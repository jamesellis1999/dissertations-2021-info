# %%
#Import basic packages
import os
import numpy as np
import pandas as pd
import csv

# %%
#import organizations.csv
org_df = pd.read_csv(R"d:\\msc-project\data\bulk_export_122020\organizations.csv",encoding='utf-8')

# %%
#check column name for organisation
org_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
org_df.head(2)
# Out:
#                                    uuid      name          type permalink  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization  wetpaint
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization      zoho
#
#                                              cb_url      rank  \
# 0  https://www.crunchbase.com/organization/wetpaint  131437.0
# 1      https://www.crunchbase.com/organization/zoho    7682.0
#
#             created_at           updated_at legal_name             roles  ...  \
# 0  2007-05-25 13:51:27  2019-06-24 22:19:25        NaN           company  ...
# 1  2007-05-26 02:30:28  2018-10-27 00:29:49        NaN  investor,company  ...
#
#           phone                       facebook_url  \
# 0  206-859-6300  https://www.facebook.com/Wetpaint
# 1           NaN       http://www.facebook.com/zoho
#
#                                         linkedin_url  \
# 0          https://www.linkedin.com/company/wetpaint
# 1  http://www.linkedin.com/company/zoho-corporati...
#
#                       twitter_url  \
# 0  https://twitter.com/wetpainttv
# 1         http://twitter.com/zoho
#
#                                             logo_url alias1 alias2 alias3  \
# 0  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
# 1  https://res.cloudinary.com/crunchbase-producti...    NaN    NaN    NaN
#
#   primary_role num_exits
# 0      company       NaN
# 1      company       1.0
#
# [2 rows x 41 columns]

# %%
#Show the value of NaN for every colum
org_df.isnull().sum(axis = 0)
# Out:
# uuid                                 0
# name                                14
# type                                 0
# permalink                            7
# cb_url                               6
# rank                               134
# created_at                           0
# updated_at                           0
# legal_name                     1035917
# roles                             8873
# domain                           79212
# homepage_url                     79211
# country_code                    191226
# state_code                      761292
# region                          191226
# city                            191226
# address                         654274
# postal_code                     684663
# status                               0
# short_description                  118
# category_list                    78059
# category_groups_list             78059
# num_funding_rounds             1024489
# total_funding_usd              1075897
# total_funding                  1075897
# total_funding_currency_code    1075897
# founded_on                      260307
# last_funding_on                1024500
# closed_on                      1202566
# employee_count                       0
# email                           462846
# phone                           405981
# facebook_url                    575710
# linkedin_url                    646209
# twitter_url                     631355
# logo_url                        189098
# alias1                         1032827
# alias2                         1183539
# alias3                         1202240
# primary_role                         0
# num_exits                      1198771
# dtype: int64

# %%
#Delete unecessary columns
org_df_v1 = org_df.drop (columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
                                    'updated_at','roles', 'domain','alias1',
                                    'alias2', 'alias3'])

# %%
org_df_v1.columns
# Out:
# Index(['uuid', 'name', 'legal_name', 'homepage_url', 'country_code',
#        'state_code', 'region', 'city', 'address', 'postal_code', 'status',
#        'short_description', 'category_list', 'category_groups_list',
#        'num_funding_rounds', 'total_funding_usd', 'total_funding',
#        'total_funding_currency_code', 'founded_on', 'last_funding_on',
#        'closed_on', 'employee_count', 'email', 'phone', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
org_df_v1['num_funding_rounds'].unique()
# Out:
# array([ 3., nan,  6., 17.,  1., 11.,  4.,  5.,  2.,  7., 16.,  8., 14.,
#        10.,  9., 12., 13., 15., 35., 21., 23., 19., 20., 18., 29., 22.,
#        31., 24., 27., 25.,  0., 41., 34., 30., 36.])

# %%
#delete data with no founded date, country code, and category
org_df_v2 = org_df_v1.dropna (subset=['founded_on','country_code','category_list','category_groups_list'])

# %%
len(org_df_v2)
# Out:
# 827800

# %%
org_df_v2.rename(columns = {'uuid':'org_uuid'},inplace=True)
# Out:
# C:\Users\Abdul Rahim Ab Ghani\miniconda3\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#filter only company data
org_df_v3 = org_df_v2[org_df_v2.primary_role == 'company']

# %%
len(org_df_v3)
# Out:
# 803301

# %% [markdown]
# # Organization Description

# %%
#import organisations description.csv
org_desc_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/organization_descriptions.csv",encoding='utf-8')

# %%
org_desc_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'description'],
#       dtype='object')

# %%
#drop uneseccary columns
org_desc_df_v1 = org_desc_df.drop(columns = ['name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
org_desc_df_v1.columns
# Out:
# Index(['uuid', 'description'], dtype='object')

# %%
org_desc_df_v1.rename(columns={'uuid':'org_uuid'},inplace=True)

# %%
org_desc_df_v1.columns
# Out:
# Index(['org_uuid', 'description'], dtype='object')

# %%
#combine with main org file
main_org_df_v1 = pd.merge (org_df_v3,org_desc_df_v1,
                         how='left',
                         on='org_uuid'
                         )

# %%
main_org_df_v1.columns
# Out:
# Index(['org_uuid', 'name', 'legal_name', 'homepage_url', 'country_code',
#        'state_code', 'region', 'city', 'address', 'postal_code', 'status',
#        'short_description', 'category_list', 'category_groups_list',
#        'num_funding_rounds', 'total_funding_usd', 'total_funding',
#        'total_funding_currency_code', 'founded_on', 'last_funding_on',
#        'closed_on', 'employee_count', 'email', 'phone', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'primary_role', 'num_exits',
#        'description'],
#       dtype='object')

# %%
len(main_org_df_v1)
# Out:
# 803301

# %% [markdown]
# # IPOs

# %%
#import ipos.csv
ipos_df = pd.read_csv(R"d:\\msc-project\data\bulk_export_122020\ipos.csv",encoding='utf-8')

# %%
ipos_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'org_uuid', 'org_name', 'org_cb_url', 'country_code',
#        'state_code', 'region', 'city', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code'],
#       dtype='object')

# %%
#drop unecessary columns
ipos_df_v1 = ipos_df.drop (columns = ['name','type','permalink', 'cb_url', 'rank', 'created_at',
       'updated_at','org_name', 'org_cb_url', 'country_code',
       'state_code', 'region', 'city'])

# %%
ipos_df_v1.columns
# Out:
# Index(['uuid', 'org_uuid', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code'],
#       dtype='object')

# %%
ipos_df_v1.rename (columns = {'uuid':'ipo_uuid',},inplace=True)

# %%
#Show the value of NaN for every colum
ipos_df_v1.isnull().sum(axis = 0)
# Out:
# ipo_uuid                             0
# org_uuid                             0
# stock_exchange_symbol               60
# stock_symbol                        21
# went_public_on                       0
# share_price_usd                  30694
# share_price                      30694
# share_price_currency_code        30694
# valuation_price_usd              32946
# valuation_price                  32946
# valuation_price_currency_code    32946
# money_raised_usd                 30171
# money_raised                     30171
# money_raised_currency_code       30171
# dtype: int64

# %%
ipos_df_v1.columns
# Out:
# Index(['ipo_uuid', 'org_uuid', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code'],
#       dtype='object')

# %%
#drop duplicates and only keep the first IPO
ipos_df_v1.sort_values(by = ['org_uuid','went_public_on'],inplace=True,na_position='last',ignore_index=True)
ipos_df_v2 = ipos_df_v1.drop_duplicates(subset=['org_uuid'],keep='first')

# %%
len(ipos_df_v1)
# Out:
# 35109

# %%
len(ipos_df_v2)
# Out:
# 34276

# %%
main_org_df_v2 = pd.merge(main_org_df_v1,ipos_df_v2,
                        how = 'left',
                         on='org_uuid')

# %%
len(main_org_df_v1)
# Out:
# 803301

# %%
len(main_org_df_v2)
# Out:
# 803301

# %%
main_org_df_v2.columns
# Out:
# Index(['org_uuid', 'name', 'legal_name', 'homepage_url', 'country_code',
#        'state_code', 'region', 'city', 'address', 'postal_code', 'status',
#        'short_description', 'category_list', 'category_groups_list',
#        'num_funding_rounds', 'total_funding_usd', 'total_funding',
#        'total_funding_currency_code', 'founded_on', 'last_funding_on',
#        'closed_on', 'employee_count', 'email', 'phone', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'primary_role', 'num_exits',
#        'description', 'ipo_uuid', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code'],
#       dtype='object')

# %% [markdown]
# # Acquisitions

# %%
#import acquisitions.csv
acquisitions_df = pd.read_csv(R"d:\\msc-project\data\bulk_export_122020\acquisitions.csv",encoding='utf-8')

# %%
acquisitions_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'acquiree_uuid', 'acquiree_name', 'acquiree_cb_url',
#        'acquiree_country_code', 'acquiree_state_code', 'acquiree_region',
#        'acquiree_city', 'acquirer_uuid', 'acquirer_name', 'acquirer_cb_url',
#        'acquirer_country_code', 'acquirer_state_code', 'acquirer_region',
#        'acquirer_city', 'acquisition_type', 'acquired_on', 'price_usd',
#        'price', 'price_currency_code'],
#       dtype='object')

# %%
#drop unessary columns
acquisitions_df_v1 = acquisitions_df.drop(columns = ['name', 'type', 'permalink', 'cb_url', 'rank', 'created_at','updated_at',
        'acquiree_name', 'acquiree_cb_url','acquiree_country_code', 'acquiree_state_code', 'acquiree_region','acquiree_city','acquirer_cb_url'])

# %%
acquisitions_df_v1.columns
# Out:
# Index(['uuid', 'acquiree_uuid', 'acquirer_uuid', 'acquirer_name',
#        'acquirer_country_code', 'acquirer_state_code', 'acquirer_region',
#        'acquirer_city', 'acquisition_type', 'acquired_on', 'price_usd',
#        'price', 'price_currency_code'],
#       dtype='object')

# %%
acquisitions_df_v1.rename (columns = {'uuid':'acquisition_uuid','acquiree_uuid':'org_uuid'},inplace=True)

# %%
acquisitions_df_v1.columns
# Out:
# Index(['acquisition_uuid', 'org_uuid', 'acquirer_uuid', 'acquirer_name',
#        'acquirer_country_code', 'acquirer_state_code', 'acquirer_region',
#        'acquirer_city', 'acquisition_type', 'acquired_on', 'price_usd',
#        'price', 'price_currency_code'],
#       dtype='object')

# %%
#drop duplicate acquisition to keep only the first acquisition
acquisitions_df_v1.sort_values(by=['org_uuid','acquired_on'],na_position='last',inplace=True)
acquisitions_df_v2 = acquisitions_df_v1.drop_duplicates(subset = ['org_uuid'],keep='first')

# %%
len(acquisitions_df_v1)
# Out:
# 109215

# %%
len(acquisitions_df_v2)
# Out:
# 102447

# %%
#Show the value of NaN for every colum
acquisitions_df_v1.isnull().sum(axis = 0)
# Out:
# acquisition_uuid             0
# org_uuid                     0
# acquirer_uuid                0
# acquirer_name                0
# acquirer_country_code     1052
# acquirer_state_code      46597
# acquirer_region           1052
# acquirer_city             1052
# acquisition_type          9508
# acquired_on                  0
# price_usd                90329
# price                    90329
# price_currency_code      90329
# dtype: int64

# %%
main_org_df_v3 = pd.merge(main_org_df_v2,acquisitions_df_v2,
                        on='org_uuid'
                        ,how = 'left')

# %%
len(main_org_df_v2)
# Out:
# 803301

# %%
len(main_org_df_v3)
# Out:
# 803301

# %%
main_org_df_v3.columns
# Out:
# Index(['org_uuid', 'name', 'legal_name', 'homepage_url', 'country_code',
#        'state_code', 'region', 'city', 'address', 'postal_code', 'status',
#        'short_description', 'category_list', 'category_groups_list',
#        'num_funding_rounds', 'total_funding_usd', 'total_funding',
#        'total_funding_currency_code', 'founded_on', 'last_funding_on',
#        'closed_on', 'employee_count', 'email', 'phone', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'primary_role', 'num_exits',
#        'description', 'ipo_uuid', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code', 'acquisition_uuid', 'acquirer_uuid',
#        'acquirer_name', 'acquirer_country_code', 'acquirer_state_code',
#        'acquirer_region', 'acquirer_city', 'acquisition_type', 'acquired_on',
#        'price_usd', 'price', 'price_currency_code'],
#       dtype='object')

# %%
len(main_org_df_v3[(main_org_df_v3.num_funding_rounds <=4) & (main_org_df_v3.num_funding_rounds>0) & (main_org_df_v3.founded_on > '2010-01-01')])
# Out:
# 106258

# %% [markdown]
# # Parent Organisation

# %%
#import parents organisation.csv
parents_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/org_parents.csv",encoding='utf-8')

# %%
parents_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'parent_uuid', 'parent_name'],
#       dtype='object')

# %%
parents_df_v1 = parents_df.drop(columns=['name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
               'updated_at'])

# %%
parents_df_v1.columns
# Out:
# Index(['uuid', 'parent_uuid', 'parent_name'], dtype='object')

# %%
parents_df_v1.rename(columns={'uuid':'org_uuid'},inplace=True)

# %%
parents_df_v1.columns
# Out:
# Index(['org_uuid', 'parent_uuid', 'parent_name'], dtype='object')

# %%
main_org_df_v4 = pd.merge(main_org_df_v3,parents_df_v1,
                         on = 'org_uuid',
                         how = 'left')

# %%
len(main_org_df_v3)
# Out:
# 803301

# %%
len(main_org_df_v4)
# Out:
# 803301

# %%
main_org_df_v4.columns
# Out:
# Index(['org_uuid', 'name', 'legal_name', 'homepage_url', 'country_code',
#        'state_code', 'region', 'city', 'address', 'postal_code', 'status',
#        'short_description', 'category_list', 'category_groups_list',
#        'num_funding_rounds', 'total_funding_usd', 'total_funding',
#        'total_funding_currency_code', 'founded_on', 'last_funding_on',
#        'closed_on', 'employee_count', 'email', 'phone', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'primary_role', 'num_exits',
#        'description', 'ipo_uuid', 'stock_exchange_symbol', 'stock_symbol',
#        'went_public_on', 'share_price_usd', 'share_price',
#        'share_price_currency_code', 'valuation_price_usd', 'valuation_price',
#        'valuation_price_currency_code', 'money_raised_usd', 'money_raised',
#        'money_raised_currency_code', 'acquisition_uuid', 'acquirer_uuid',
#        'acquirer_name', 'acquirer_country_code', 'acquirer_state_code',
#        'acquirer_region', 'acquirer_city', 'acquisition_type', 'acquired_on',
#        'price_usd', 'price', 'price_currency_code', 'parent_uuid',
#        'parent_name'],
#       dtype='object')

# %%
main_org_df_v4.isnull().sum(axis=0)
# Out:
# org_uuid                              0
# name                                  0
# legal_name                       668373
# homepage_url                      23970
# country_code                          0
# state_code                       457683
# region                                0
# city                                  0
# address                          368720
# postal_code                      386229
# status                                0
# short_description                     8
# category_list                         0
# category_groups_list                  0
# num_funding_rounds               626316
# total_funding_usd                669965
# total_funding                    669965
# total_funding_currency_code      669965
# founded_on                            0
# last_funding_on                  626325
# closed_on                        793528
# employee_count                        0
# email                            240900
# phone                            198487
# facebook_url                     328645
# linkedin_url                     341368
# twitter_url                      373086
# logo_url                          79494
# primary_role                          0
# num_exits                        800019
# description                      350280
# ipo_uuid                         773058
# stock_exchange_symbol            773107
# stock_symbol                     773074
# went_public_on                   773058
# share_price_usd                  799219
# share_price                      799219
# share_price_currency_code        799219
# valuation_price_usd              801277
# valuation_price                  801277
# valuation_price_currency_code    801277
# money_raised_usd                 798742
# money_raised                     798742
# money_raised_currency_code       798742
# acquisition_uuid                 723507
# acquirer_uuid                    723507
# acquirer_name                    723507
# acquirer_country_code            724074
# acquirer_state_code              756169
# acquirer_region                  724074
# acquirer_city                    724074
# acquisition_type                 730728
# acquired_on                      723507
# price_usd                        789022
# price                            789022
# price_currency_code              789022
# parent_uuid                      794189
# parent_name                      794189
# dtype: int64

# %% [markdown]
# # Funding Rounds

# %%
#import funding_rounds
funding_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/funding_rounds.csv",encoding='utf-8')

# %%
funding_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'country_code', 'state_code', 'region', 'city',
#        'investment_type', 'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code', 'post_money_valuation_usd',
#        'post_money_valuation', 'post_money_valuation_currency_code',
#        'investor_count', 'org_uuid', 'org_name', 'lead_investor_uuids'],
#       dtype='object')

# %%
#drop unecessary columns
funding_df_v1 = funding_df.drop(columns=['type','permalink', 'cb_url', 'rank', 'created_at',
                'updated_at'])

# %%
funding_df_v1.columns
# Out:
# Index(['uuid', 'name', 'country_code', 'state_code', 'region', 'city',
#        'investment_type', 'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code', 'post_money_valuation_usd',
#        'post_money_valuation', 'post_money_valuation_currency_code',
#        'investor_count', 'org_uuid', 'org_name', 'lead_investor_uuids'],
#       dtype='object')

# %%
funding_df_v1.investment_type.unique()
# Out:
# array(['angel', 'series_a', 'series_b', 'seed', 'series_c', 'series_d',
#        'series_unknown', 'debt_financing', 'series_e', 'private_equity',
#        'series_f', 'pre_seed', 'undisclosed', 'grant', 'convertible_note',
#        'post_ipo_equity', 'post_ipo_debt', 'non_equity_assistance',
#        'corporate_round', 'series_i', 'series_g', 'secondary_market',
#        'initial_coin_offering', 'series_h', 'product_crowdfunding',
#        'equity_crowdfunding', 'post_ipo_secondary', 'series_j'],
#       dtype=object)

# %%
funding_df_v1.rename(columns={'uuid':'funding_round_uuid'},inplace=True)

# %%
funding_df_v1.columns
# Out:
# Index(['funding_round_uuid', 'name', 'country_code', 'state_code', 'region',
#        'city', 'investment_type', 'announced_on', 'raised_amount_usd',
#        'raised_amount', 'raised_amount_currency_code',
#        'post_money_valuation_usd', 'post_money_valuation',
#        'post_money_valuation_currency_code', 'investor_count', 'org_uuid',
#        'org_name', 'lead_investor_uuids'],
#       dtype='object')

# %%
#check for NaN value
funding_df_v1.isnull().sum(axis=0)
# Out:
# funding_round_uuid                         0
# name                                       0
# country_code                            4237
# state_code                            172992
# region                                  4237
# city                                    4237
# investment_type                            0
# announced_on                               0
# raised_amount_usd                      98961
# raised_amount                          98961
# raised_amount_currency_code            98961
# post_money_valuation_usd              346299
# post_money_valuation                  346299
# post_money_valuation_currency_code    346299
# investor_count                        101823
# org_uuid                                   0
# org_name                                   2
# lead_investor_uuids                   238258
# dtype: int64

# %% [markdown]
# # Investment

# %%
#import investment
investments_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/investments.csv",encoding='utf-8')

# %%
investments_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'funding_round_uuid', 'funding_round_name',
#        'investor_uuid', 'investor_name', 'investor_type', 'is_lead_investor'],
#       dtype='object')

# %%
#drop columns
investments_df_v1 = investments_df.drop(columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
investments_df_v1.columns
# Out:
# Index(['uuid', 'name', 'funding_round_uuid', 'funding_round_name',
#        'investor_uuid', 'investor_name', 'investor_type', 'is_lead_investor'],
#       dtype='object')

# %%
investments_df_v1.rename(columns={'uuid':'investment_uuid'},inplace=True)

# %%
investments_df_v1.columns
# Out:
# Index(['investment_uuid', 'name', 'funding_round_uuid', 'funding_round_name',
#        'investor_uuid', 'investor_name', 'investor_type', 'is_lead_investor'],
#       dtype='object')

# %%
investments_df_v1.isnull().sum(axis=0)
# Out:
# investment_uuid            0
# name                       1
# funding_round_uuid         1
# funding_round_name         1
# investor_uuid              0
# investor_name              1
# investor_type              0
# is_lead_investor      283147
# dtype: int64

# %% [markdown]
# # Investors

# %%
#import investors
investors_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/investors.csv",encoding='utf-8')

# %%
investors_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'roles', 'domain', 'country_code', 'state_code', 'region',
#        'city', 'investor_types', 'investment_count', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'closed_on', 'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
investors_df.head(3)
# Out:
#                                    uuid             name          type  \
# 0  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 1  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 2  df662812-7f97-0b43-9d3e-12f64f504fbb         Facebook  organization
#
#          permalink                                             cb_url    rank  \
# 0             zoho       https://www.crunchbase.com/organization/zoho  7694.0
# 1  omidyar-network  https://www.crunchbase.com/organization/omidya...  1758.0
# 2         facebook   https://www.crunchbase.com/organization/facebook     5.0
#
#             created_at           updated_at             roles        domain  \
# 0  2007-05-26 02:30:28  2018-10-27 00:29:49  investor,company      zoho.com
# 1  2007-05-26 03:21:34  2019-06-19 12:17:48          investor   omidyar.com
# 2  2007-05-26 04:22:15  2020-10-21 13:53:15  investor,company  facebook.com
#
#    ... investment_count total_funding_usd total_funding  \
# 0  ...              6.0               NaN           NaN
# 1  ...            313.0               NaN           NaN
# 2  ...             32.0      1.612282e+10  1.612282e+10
#
#   total_funding_currency_code  founded_on  closed_on  \
# 0                         NaN  1996-09-15        NaN
# 1                         NaN  2004-01-01        NaN
# 2                         USD  2004-02-04        NaN
#
#                              facebook_url  \
# 0            http://www.facebook.com/zoho
# 1  http://www.facebook.com/OmidyarNetwork
# 2      https://www.facebook.com/facebook/
#
#                                         linkedin_url  \
# 0  http://www.linkedin.com/company/zoho-corporati...
# 1              http://www.linkedin.com/company/22806
# 2           http://www.linkedin.com/company/facebook
#
#                          twitter_url  \
# 0            http://twitter.com/zoho
# 1  http://twitter.com/OmidyarNetwork
# 2       https://twitter.com/facebook
#
#                                             logo_url
# 0  https://res.cloudinary.com/crunchbase-producti...
# 1  https://res.cloudinary.com/crunchbase-producti...
# 2  https://res.cloudinary.com/crunchbase-producti...
#
# [3 rows x 25 columns]

# %%
investors_df_v1 = investors_df.drop(columns=['permalink', 'cb_url', 'rank', 'created_at',
       'updated_at', 'roles','domain'])

# %%
investors_df_v1.columns
# Out:
# Index(['uuid', 'name', 'type', 'country_code', 'state_code', 'region', 'city',
#        'investor_types', 'investment_count', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'closed_on', 'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
investors_df_v1.rename(columns={'uuid':'investor_uuid'},inplace=True)

# %%
investors_df_v1.columns
# Out:
# Index(['investor_uuid', 'name', 'type', 'country_code', 'state_code', 'region',
#        'city', 'investor_types', 'investment_count', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'closed_on', 'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
investors_df_v1.isnull().sum(axis=0)
# Out:
# investor_uuid                       0
# name                                2
# type                                0
# country_code                    53898
# state_code                     112472
# region                          57935
# city                            59582
# investor_types                  81201
# investment_count                83892
# total_funding_usd              162641
# total_funding                  162641
# total_funding_currency_code    162641
# founded_on                     121592
# closed_on                      166366
# facebook_url                   137548
# linkedin_url                    78483
# twitter_url                    124010
# logo_url                        42484
# dtype: int64

# %% [markdown]
# # Investment Partner

# %%
#import investment partner
investment_partner_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/investment_partners.csv",encoding='utf-8')

# %%
investment_partner_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'funding_round_uuid', 'funding_round_name',
#        'investor_uuid', 'investor_name', 'partner_uuid', 'partner_name'],
#       dtype='object')

# %%
investment_partner_df.head(2)
# Out:
#                                    uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d
# 1  524986f0-3049-54a4-fa72-f60897a5e61d
#
#                                       name        type  \
# 0  Accel investment in Series A - Facebook  investment
# 1  Accel investment in Series A - Facebook  investment
#
#                                            permalink  \
# 0  accel-invested-in-facebook-series-a--d950d7a5-...
# 1  accel-invested-in-facebook-series-a--d950d7a5-...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/investment/accel-in...   NaN
# 1  https://www.crunchbase.com/investment/accel-in...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-27 06:09:10  2018-02-13 00:52:57
# 1  2007-05-27 06:09:10  2018-02-13 00:52:57
#
#                      funding_round_uuid   funding_round_name  \
# 0  d950d7a5-79ff-fb93-ca87-13386b0e2feb  Series A - Facebook
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb  Series A - Facebook
#
#                           investor_uuid investor_name  \
# 0  b08efc27-da40-505a-6f9d-c9e14247bf36         Accel
# 1  b08efc27-da40-505a-6f9d-c9e14247bf36         Accel
#
#                            partner_uuid  partner_name
# 0  2d78d1e7-203c-3eb6-bf1b-c51f10e0679b    Jim Breyer
# 1  eaf6c243-d355-32f3-e23a-2a5fc82e8b34  Kevin Efrusy

# %%
#drop unecessary columns
investment_partner_df_v1 = investment_partner_df.drop(columns=['name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at', 'funding_round_uuid', 'funding_round_name',
       'investor_uuid', 'investor_name'])

# %%
investment_partner_df_v1.rename (columns={'uuid':'investment_uuid'},inplace=True)

# %%
investment_partner_df_v1.columns
# Out:
# Index(['investment_uuid', 'partner_uuid', 'partner_name'], dtype='object')

# %%
#merge with investments df
main_investments_v1 = pd.merge (investments_df_v1,investment_partner_df_v1,
                              on='investment_uuid',
                              how='left')

# %%
len(investments_df_v1)
# Out:
# 548451

# %%
len(main_investments_v1)
# Out:
# 558071

# %%
main_investments_v1.columns
# Out:
# Index(['investment_uuid', 'name', 'funding_round_uuid', 'funding_round_name',
#        'investor_uuid', 'investor_name', 'investor_type', 'is_lead_investor',
#        'partner_uuid', 'partner_name'],
#       dtype='object')

# %% [markdown]
# # Funds

# %%
funds_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/funds.csv",encoding='utf-8')

# %%
funds_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'entity_uuid', 'entity_name', 'entity_type',
#        'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code'],
#       dtype='object')

# %%
funds_df.head(2)
# Out:
#                                    uuid                    name  type  \
# 0  8190b28a-3c78-0ac4-1e7c-f0b5edce4b2e  DFJ Dragon Second Fund  fund
# 1  cbb6644a-eafb-4686-5505-61f32e1c3638  Sequoia Israel Fund IV  fund
#
#                                            permalink  \
# 0  dfj-dragonfund-raised-dfj-dragon-second-fund--...
# 1  sequoia-capital-raised-sequoia-israel-fund-iv-...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/fund/dfj-dragonfund...   NaN
# 1  https://www.crunchbase.com/fund/sequoia-capita...   NaN
#
#             created_at           updated_at  \
# 0  2008-12-17 03:07:16  2018-02-12 23:51:25
# 1  2008-12-18 22:04:42  2018-02-13 00:38:07
#
#                             entity_uuid      entity_name   entity_type  \
# 0  fe743289-a4aa-a470-00d8-bbe937e0955b   DFJ DragonFund  organization
# 1  0c867fde-2b9a-df10-fdb9-66b74f355f91  Sequoia Capital  organization
#
#   announced_on  raised_amount_usd  raised_amount raised_amount_currency_code
# 0   2008-12-16        300000000.0    300000000.0                         USD
# 1   2008-12-17        200750000.0    200750000.0                         USD

# %%
funds_df_v1 = funds_df.drop(columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
funds_df_v1.isnull().sum(axis=0)
# Out:
# uuid                              0
# name                              0
# entity_uuid                       0
# entity_name                       0
# entity_type                       0
# announced_on                    301
# raised_amount_usd              2927
# raised_amount                  2919
# raised_amount_currency_code    2919
# dtype: int64

# %%
funds_df_v1.rename(columns={'uuid':'fund_uuid','entity_uuid':'org_uuid'},inplace=True)

# %%
funds_df_v1.columns
# Out:
# Index(['fund_uuid', 'name', 'org_uuid', 'entity_name', 'entity_type',
#        'announced_on', 'raised_amount_usd', 'raised_amount',
#        'raised_amount_currency_code'],
#       dtype='object')

# %% [markdown]
# # Events

# %%
#import events.csv
events_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/events.csv",encoding='utf-8')

# %%
events_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'short_description', 'started_on', 'ended_on',
#        'event_url', 'registration_url', 'venue_name', 'description',
#        'country_code', 'state_code', 'region', 'city', 'logo_url',
#        'event_roles'],
#       dtype='object')

# %%
events_df.head(3)
# Out:
#                                    uuid              name   type  \
# 0  6a21f93a-3cae-02ac-44c7-c166c0ed50fa       SF New Tech  event
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2    Adobe MAX 2014  event
# 2  c6006d9f-e796-2a2a-2efc-c4e55caa98f8  ad:tech New York  event
#
#                            permalink  \
# 0          sfnt-201272-san-francisco
# 1      adobe-max-2014104-los-angeles
# 2  ad-tech-new-york-2014105-new-york
#
#                                               cb_url     rank  \
# 0  https://www.crunchbase.com/event/sfnt-201272-s...  18739.0
# 1  https://www.crunchbase.com/event/adobe-max-201...   8883.0
# 2  https://www.crunchbase.com/event/ad-tech-new-y...   8346.0
#
#             created_at           updated_at  \
# 0  2014-10-03 18:12:25  2018-02-13 01:14:28
# 1  2014-10-03 18:14:15  2018-02-13 01:14:24
# 2  2014-10-03 18:40:03  2018-02-13 01:14:23
#
#                                    short_description  started_on  ...  \
# 0  Join us on Wed, Oct 15th for another edition o...  2014-10-14  ...
# 1  Sessions, labs, and creativity workshops where...  2014-10-04  ...
# 2  ad:tech New York will showcase keynote speaker...  2014-10-05  ...
#
#   event_url                       registration_url  \
# 0       NaN  http://1015sfnt-meetup.eventbrite.com
# 1       NaN     http://max.adobe.com/registration/
# 2       NaN     http://ad-tech.com/ny/registration
#
#                       venue_name description country_code state_code  \
# 0                  RocketStudios         NaN          USA         CA
# 1  Los Angeles Convention Center         NaN          USA         CA
# 2                  Javits Center         NaN          USA         NY
#
#        region           city  \
# 0  California  San Francisco
# 1  California    Los Angeles
# 2    New York       New York
#
#                                             logo_url event_roles
# 0                                                NaN  conference
# 1  https://res.cloudinary.com/crunchbase-producti...  conference
# 2  https://res.cloudinary.com/crunchbase-producti...  conference
#
# [3 rows x 21 columns]

# %%
events_df_v1 = events_df.drop (columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at','event_url', 'registration_url', 'venue_name','logo_url'])

# %%
events_df_v1.rename(columns = {'uuid':'event_uuid'},inplace=True)

# %%
events_df_v1.columns
# Out:
# Index(['event_uuid', 'name', 'short_description', 'started_on', 'ended_on',
#        'description', 'country_code', 'state_code', 'region', 'city',
#        'event_roles'],
#       dtype='object')

# %% [markdown]
# # Event Appearances

# %%
#import event_appearances.csv
event_appear_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/event_appearances.csv",encoding='utf-8')

# %%
event_appear_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'event_uuid', 'event_name', 'participant_uuid',
#        'participant_name', 'participant_type', 'appearance_type',
#        'short_description'],
#       dtype='object')

# %%
event_appear_df.head(3)
# Out:
#                                    uuid  \
# 0  30c4023d-b694-4704-97d7-cd99cd06ecce
# 1  dffe0542-3dac-4228-a997-3eed42cbd67e
# 2  21884e6c-d097-4c54-8513-10536a0ea60d
#
#                                          name              type  \
# 0  Adobe MAX 2014's sponsor - CDW Corporation  event_appearance
# 1        Adobe MAX 2014's sponsor - Microsoft  event_appearance
# 2          Adobe MAX 2014's sponsor - Twitter  event_appearance
#
#                                            permalink  \
# 0  cdw-corporation-sponsor-adobe-max-2014104-los-...
# 1  microsoft-sponsor-adobe-max-2014104-los-angele...
# 2  twitter-sponsor-adobe-max-2014104-los-angeles-...
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/event_appearance/cd...   NaN
# 1  https://www.crunchbase.com/event_appearance/mi...   NaN
# 2  https://www.crunchbase.com/event_appearance/tw...   NaN
#
#             created_at           updated_at  \
# 0  2014-10-03 18:21:26  2018-02-13 01:16:54
# 1  2014-10-03 18:21:42  2018-02-13 01:16:21
# 2  2014-10-03 18:21:55  2018-02-13 01:16:23
#
#                              event_uuid      event_name  \
# 0  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 1  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
# 2  135a927a-b238-037e-50e2-d3a2e3511ed2  Adobe MAX 2014
#
#                        participant_uuid participant_name participant_type  \
# 0  ae883a31-3739-7eb9-4ce0-463ee070ed79  CDW Corporation     organization
# 1  fd80725f-53fc-7009-9878-aeecf1e9ffbb        Microsoft     organization
# 2  5da6106f-0d27-0d37-e9d7-dcfeccc1f709          Twitter     organization
#
#   appearance_type short_description
# 0         sponsor               NaN
# 1         sponsor               NaN
# 2         sponsor               NaN

# %%
#drop unecessary columns
event_appear_df_v1 = event_appear_df.drop (columns = ['permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
event_appear_df_v1.columns
# Out:
# Index(['uuid', 'name', 'type', 'event_uuid', 'event_name', 'participant_uuid',
#        'participant_name', 'participant_type', 'appearance_type',
#        'short_description'],
#       dtype='object')

# %%
event_appear_df_v1.participant_type.unique()
# Out:
# array(['organization', 'person'], dtype=object)

# %%
event_appear_df_v1.appearance_type.unique()
# Out:
# array(['sponsor', 'speaker', 'organizer', 'exhibitor', 'contestant'],
#       dtype=object)

# %% [markdown]
# # People

# %%
#import people.csv
people_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/people.csv",encoding='utf-8')

# %%
people_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'first_name', 'last_name', 'gender', 'country_code',
#        'state_code', 'region', 'city', 'featured_job_organization_uuid',
#        'featured_job_organization_name', 'featured_job_title', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
#drop unecessary column
people_df_v1 = people_df.drop(columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
people_df_v1.columns
# Out:
# Index(['uuid', 'name', 'first_name', 'last_name', 'gender', 'country_code',
#        'state_code', 'region', 'city', 'featured_job_organization_uuid',
#        'featured_job_organization_name', 'featured_job_title', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
#change column name
people_df_v1.rename (columns = {'uuid':'people_uuid','featured_job_organization_uuid':'org_uuid'},inplace=True)

# %%
people_df_v1.head(3)
# Out:
#                             people_uuid            name first_name last_name  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz        Ben   Elowitz
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty      Kevin  Flaherty
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna       Raju   Vegesna
#
#   gender country_code state_code      region           city  \
# 0   male          USA         WA  Washington        Seattle
# 1   male          NaN        NaN         NaN            NaN
# 2   male          USA         CA  California  San Francisco
#
#                                org_uuid featured_job_organization_name  \
# 0  cf253887-5eac-21a2-28d3-47db7311f7e9          Madrona Venture Group
# 1  789e5e4d-0c90-d06e-92a0-b800b461c3da                       DRSmedia
# 2  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
#
#   featured_job_title                     facebook_url  \
# 0  Managing Director  http://www.facebook.com/elowitz
# 1        Team Member                              NaN
# 2   Chief Evangelist                              NaN
#
#                                         linkedin_url  \
# 0               https://www.linkedin.com/in/elowitz/
# 1           http://www.linkedin.com/in/kevinflaherty
# 2  https://www.linkedin.com/pub/raju-vegesna/1/65...
#
#                   twitter_url  \
# 0  http://twitter.com/elowitz
# 1  https://twitter.com/tallkp
# 2                         NaN
#
#                                             logo_url
# 0  https://res.cloudinary.com/crunchbase-producti...
# 1  https://res.cloudinary.com/crunchbase-producti...
# 2  https://res.cloudinary.com/crunchbase-producti...

# %%
#Check number of NA value
people_df_v1.isnull().sum(axis=0)
# Out:
# people_uuid                             0
# name                                    0
# first_name                             31
# last_name                              30
# gender                              21326
# country_code                       481302
# state_code                         781037
# region                             526030
# city                               542070
# org_uuid                           424214
# featured_job_organization_name     424215
# featured_job_title                 424228
# facebook_url                      1004027
# linkedin_url                       465506
# twitter_url                        905142
# logo_url                           287433
# dtype: int64

# %%
len(people_df_v1)
# Out:
# 1099621

# %% [markdown]
# # People Description

# %%
#import people.csv
people_desc_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/people_descriptions.csv",encoding='utf-8')

# %%
people_desc_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'description'],
#       dtype='object')

# %%
#drop unecessary columns
people_desc_df_v1 = people_desc_df.drop (columns=['name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
people_desc_df_v1.columns
# Out:
# Index(['uuid', 'description'], dtype='object')

# %%
#change column name
people_desc_df_v1.rename(columns = {'uuid':'people_uuid'},inplace=True)

# %%
#check NA
people_desc_df_v1.isnull().sum(axis=0)
# Out:
# people_uuid     0
# description    12
# dtype: int64

# %%
#drop data with NA
people_desc_df_v2 = people_desc_df_v1.dropna (subset=['description'])

# %%
#merge with main people data
main_people_df_v1 = pd.merge(people_df_v1,
                            people_desc_df_v2,
                            on='people_uuid',
                            how='left')

# %%
main_people_df_v1.columns
# Out:
# Index(['people_uuid', 'name', 'first_name', 'last_name', 'gender',
#        'country_code', 'state_code', 'region', 'city', 'org_uuid',
#        'featured_job_organization_name', 'featured_job_title', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'description'],
#       dtype='object')

# %% [markdown]
# # Degrees

# %%
#import degress.csv
deg_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/degrees.csv",encoding='utf-8')

# %%
deg_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'person_uuid', 'person_name', 'institution_uuid',
#        'institution_name', 'degree_type', 'subject', 'started_on',
#        'completed_on', 'is_completed'],
#       dtype='object')

# %%
deg_df.head(2)
# Out:
#                                    uuid  \
# 0  205fdfd1-ecac-aa43-262f-219f11755f67
# 1  1a2ac288-eb99-3318-fde5-1517bc168f51
#
#                                                 name    type  permalink  \
# 0         MS  Mass Communication @ Boston University  degree        NaN
# 1  BA  English, French @ Washington University in...  degree        NaN
#
#    cb_url  rank           created_at           updated_at  \
# 0     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:40:03
# 1     NaN   NaN  2008-02-19 17:58:31  2018-02-13 01:39:57
#
#                             person_uuid person_name  \
# 0  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
# 1  4897dba9-3141-ecc0-2c4b-c9d844e6440f  John Green
#
#                        institution_uuid                    institution_name  \
# 0  1eab62d2-15d9-0db7-930f-2aa77d4688e1                   Boston University
# 1  6ae9957a-8fb4-0ab1-73fa-dd547c4d3da4  Washington University in St. Louis
#
#   degree_type             subject started_on completed_on  is_completed
# 0          MS  Mass Communication        NaN   1992-01-01          True
# 1          BA     English, French        NaN   1990-01-01          True

# %%
#drop uncessary columns
deg_df_v2 = deg_df.drop(columns = ['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
deg_df_v2.columns
# Out:
# Index(['uuid', 'name', 'person_uuid', 'person_name', 'institution_uuid',
#        'institution_name', 'degree_type', 'subject', 'started_on',
#        'completed_on', 'is_completed'],
#       dtype='object')

# %%
#change column name
deg_df_v2.rename(columns = {'uuid':'deg_uuid','name':'deg_name','person_uuid':'people_uuid'},inplace=True)

# %%
deg_df_v2.columns
# Out:
# Index(['deg_uuid', 'deg_name', 'people_uuid', 'person_name',
#        'institution_uuid', 'institution_name', 'degree_type', 'subject',
#        'started_on', 'completed_on', 'is_completed'],
#       dtype='object')

# %%
deg_type = deg_df_v2.degree_type.unique()

# %%
for deg in deg_type:
    print (deg)
# Out:
# MS
# BA
# BS
# Bachelor of Science
# unknown
# M.A.
# LL.B
# Ph.D
# MBA
# BFA
# B.A.
# Bachelor Engineering
# M.S.
# BE
# B.S
# BASc
# JD
# M.B.A.
# B.S.
# MA
# MD
# SB
# Certificate
# B.A
# M.Phil
# BBA
# Master
# M.Math
# LL.M
# B.Tech
# M.Div.
# Ph.D.
# B.Eng
# MPA
# Bachelors
# M.A
# Master's Degree
# CEMS Master
# B.Com
# MSE
# Executive Education
# B.Sc.
# Sc.B
# J.D.
# AB
# BSE
# nan
# BBS
# AS
# M.Sc
# M.E.
# BS Engineering
# MEA
# BSC
# Graduate
# MM
# M.F.A.
# AA
# Masters
# Post Graduate
# BIS
# BArts
# Master's
# M.Eng
# Diploma
# MPS
# EDM
# MD/Ph.D
# MCA
# Bc.
# License
# DEA
# BSe
# PhD
# Exec. MBA, taught by Kellogg Professors with degree signed by Kellogg's Dean
# Honors
# Postgraduate
# LLB
# A.A.
# MSc
# M.S
# bachelor
# BSJ
# M.Ed.
# B.B.A
# M.B.A
# Bachelor of Arts
# HND
# BCA
# Undergrad
# PGCE
# Dropped Out
# MNA
# BSc.
# JBA
# D.Phil
# B.E
# Master Degree
# B.B.A.
# ME
# MPP
# ScD
# Executive Seminar
# Bachelor
# MSEE
# GMP
# Bachelor's Degree
# B.Sc
# Msc
# MPA, LPP
# dipl. Ing.
# Master of Science
# Postgraduate Diploma
# BSFS
# BSc (Hons)
# BSCE
# FdA
# BSME
# L.L.B
# B.Math
# MIS
# MED
# Master of Business Administration - MBA
# BASC
# BA/MA
# MSF
# HBA
# M.Com
# M.I.A.
# EE
# BS/MS Engineering
# Bachelor's degree
# Doctor's degree
# Bachelors in Science in Management (BSM)
# Graduation
# Credits
# Marketing Management Certificate
# B.Med
# Bachelor's degree in science
# MID
# MLIS
# Finance
# BAA
# General Course
# B.Bus
# BSc
# HSC
# BGS
# M.Sc.
# BBM
# SM
# MIMS
# MPH
# Master of Science (MS)
# B. Eng.
# PGDM
# Eng
# Bachelor's
# Bsc
# BA/MS
# MLitt
# B.Econ
# Master (advanced)
# Bachelor of Science (B.S.)
# Leave of absence: BS
# BA (First class)
# Bachelor's degree in arts
# Master's degree in business administration
# MCS
# BHA
# M.Math.
# Bachelor or Science
# operations research, applied mathematics
# B.Arch
# Bachelors of Science
# BSBA
# BEc
# B.S.E.
# BM
# MS Studies
# Degree
# MBA/MPH
# B.Eng (Hons)
# Special Studies
# EngD
# Business
# Juris Doctor
# Computer Science Diploma with distinction
# M.St.
# BIT
# Bachelor of Technology (Honors)
# M.P.H.
# B.Mus
# B.comm
# EECS
# Magister Artium M.A.
# Fellowship
# M Sc.
# M.S.E.E.
# B.Ed
# B.Mus.
# B.Sc. Hons
# B.Des
# B.S.B.A.
# B.A.Sc
# BaSc.
# HEC-Entrepreneurs
# bachelors of arts
# B.A.Sc.
# BInfoTech
# Bachelor of Electrical Engineer
# Post Doctoral
# AAS
# B.S. in Business Administration
# BA with Honors
# M.Eng.
# MIBA
# SCPD
# B.Comp
# MA, BAI
# BEng
# MS/MSE
# Master Exchange.
# M.Des
# BS Commerce
# BA(Hons)
# Bachelor of Science (Double Major)
# Bachelors of Science in Business Administration
# Business Admin
# A.B.
# M.D.
# MFA
# BCert
# B.Sc. Software Engineering
# AMP
# Bs Business Studies
# MIA
# Associate degree
# HNC
# Bachellors in Science, w Honors
# MFA, Critical Studies
# A.B
# Btech
# BS & BFP
# MBA with Distinction
# Engineering
# Executive MBA
# B.F.A.
# B.A. IT
# MSIT
# M.Tech
# Master of Science in Business Administration
# B.Tech.
# Master's of Design
# MTM
# MALD Law & Diplomacy
# PMD
# BA (with Honors)
# J.D
# L.L.M
# B.S.E
# Bachelor of Science, Honours
# Executive Education in Design Thinking
# Professor
# Master's degree
# MHA
# BSEE
# B.S.B.A
# Bachelor of Business
# BA,BS
# Masters Certificate
# MEng
# B.Comp.
# M.Div
# Post-Graduate
# BSc Honors
# Doctor of Law (JD)
# MSc.
# S1
# Dropout
# BBR
# MES
# None
# Bachelors (drop-out)
# MCP
# AAB
# Bachelors-Cum Laude
# Honours
# BTS
# Postdoctoral
# Certification
# M.S. & MBA
# Master's degree in busines administration
# MoE
# MFA -Masters Degree
# B.Sc. in Economics
# BAS
# Design MBA
# DDS
# MS & PhD
# Doctorate
# Sc.D.
# Doctor of Humane Letters (D.H.L)
# Advanced Diploma
# Graduate Certificate
# MSc in Management
# AP
# BS with High Honors
# B.E.
# BTech & MTech
# MSc in CS
# Executive
# Associate Degree
# BES
# Business Administration - Entrepneurship
# Masters of Business
# Undergraduate
# Bachelors in Technology
# Bachelors of Engineering
# Master's degree in science
# Minor
# HBSc
# DSc
# B.Sc., M.Eng., Ph.D.
# Master in Management
# Bsc.
# BA & BS
# BMS
# Computer Science
# AI & HCI
# EMBA
# Web Interface
# Business School
# MBT
# MBBS
# B. Eng Hons
# BSc (1st class)
# MBA (Distinction)
# Bachelor's degree in technology
# Entrepreneurship
# eBachelor's Degree
# M.D
# S.B, S.M.
# B.Sc. Hons.
# Grande Ecole
# Bachelor of Design
# CTA
# Business Economics
# Bachelors of Business Science
# B.S.E.E., M.S.E.E. and Ph.D.
# M.S.B.A.
# M.Sc. Eng.
# LLM
# BCs
# Specialist (5 years)
# BS, BA
# M.Sc. (Ir.)
# M.Sc (Comp Sci)
# Diplom
# Bachleor
# B.Comm
# MFin
# Master of Arts
# OD
# Bachelor of Taxation
# B. Tech
# MBA (Sloan Fellows)
# Masters Degree
# CPA
# Dropped out to join an energy startup
# BSc. & MSc.
# Abogado
# MA Oxon
# B. Eng
# Non-degree
# Dipl.-Ing. (FH)
# B.App.Science (Computer Science) HONS.
# A.S.
# MBA (incomplete)
# Bachelor Degree
# Bachelor of Vis Com
# engineering
# LL.B. Law
# M.S.C.S.
# Master equivalent degree
# BBA-H
# B.E.Sc.
# Double degree in International Business
# PMP
# Business Administration
# Concurrent Credits
# BE Hons I
# B.J.
# Exchange programme
# Bachelor's degree in engineering
# Bachelor’s Degree
# M.P.A.
# Certificate - EEP
# Ph.D & M.S
# B.A & M.A
# DVM
# M.F.A
# Bachelors's
# B. Arch
# MsC
# Ph.D dropout
# Physics
# MBA - Q in Thailand
# B.Com.
# B.S & M.S
# Bachelor of Commerce
# Bachelors Arts
# B.Arch.
# Medical Degree
# Fellow researcher
# Ms
# Butler University
# Bachelor of Arts (B.A.)
# MTP
# B.S.F.S.
# B.Eng.
# BS/BA
# PGDST
# B.S.E.E.
# MRA
# Project Managment Certificate Program
# Management Engineer
# Bachelor' Degree
# Associate in Arts & Design
# Business Case Program
# Master of Software Engineering
# S.M.E.E.
# B.Comm.
# MIM
# MMP
# Bachelor of Applied Science
# M.P.S
# Continued Studies
# Bs
# SITN Program
# Dual BA's
# B.F.A
# NS
# Bachelor of Robotics and Digital Technology
# BEE
# L.L.B.
# Master of Science (MSc)
# Graduated
# Phd
# B.Comp.Sci
# Visiting Scholar
# B.Sci
# B.A.S.
# Doctor of Pharmacy
# Chief Capabilities Officer
# Bachelor (Honors)
# M.P.H
# Dipl.-Kfm.
# BSE/MSE
# L.L.M.
# C., Engineering
# Cert., Engineering
# Dual S.B.
# S.M.
# Coursework
# Engineer
# Master’s
# D.Sc
# Executive Management
# DPhil
# M.Ed
# Cand. oecon.
# M.E.M
# B-Tech
# Bachelors in Science
# MDE Certificate
# BbA
# MET
# MA,PHD
# M.Ac.
# AB/SM
# Lic.oec.
# Bachelors of Arts
# E.P.S.O
# Doctor
# OPM
# BCom (Honours)
# A.M.
# Master of Science (M.S.)
# Bachelors of Administrative Studies
# ALB
# B.S.M.E
# M.M.
# N/a
# Ph.D. Candidate
# Bachelor’s
# BA Hons
# Hotel Management
# M Sc
# Master / Dipl.-Ing.
# Master of Public Health (M.P.H.)
# MTS
# Government
# B. Tech.
# MA Honours
# Bachelor of Art
# A.A., Highest Honors
# BA (Hons)
# International MBA
# Doctororate
# Executive Studies
# MPD
# B.Litt.
# BS/MS Honor Program
# RN
# BSS
# MBA/MIA
# CFA
# Ed.M.
# MPhil.
# B.A.I/B.A
# B.C.M.
# SB/SM
# B.S., M.Engg
# Economy
# BTech, MTech
# M.Litt.
# Summer school course
# BChE
# B.Acc.
# LL.B.
# MS,BS
# BSCO
# M.S.E.
# BA (mod.)
# Professional Certificate
# Master of Art
# D.Phil.
# Graduate Diploma
# LL.M.
# Master's degree in arts
# BS, MS, PhD
# BCS
# BS + BA
# CSS
# Actually, Eugene was kicked out of the University after one year of study as never graduated it
# YPO
# Ph.D (Withdrew ABD)
# Juris Doctor (JD)
# Bachelor of Science (B.S)
# B.A. (HSG)
# B.E CS & E
# C.S
# Partial
# BA, BS
# (dropout)
# B.Sc & Ph.D
# Juris Doctor (J.D.)
# Ms Sc
# BA/BS
# Master II
# MB, BChir
# MAcc
# civ.ek.
# Bachlor
# Certificate Program (Extn)
# Corporate Finance
# Doctoral
# MS & BS
# BS & MS
# SM, Advanced Engineer
# Post Doctrael
# Executive Program
# lic. iur.
# Laurea
# Executive Certificate
# Integrated Masters
# Business Administration & Economics
# BSc. 1st class hons.
# MSI
# Master of Technology
# Master of Science (M.Sc.)
# MD, PhD
# M.P.P
# B.S. BME
# D.Sc.
# B.S., B.A.
# C.A.S.
# M.S.L.
# MDesS
# M.P.A
# PharmD
# Summer EMBA
# University degree
# BASc (dropped out)
# Young Global Leaders Program
# Doctor of Philosophy (Ph.D.)
# M.Phil.
# Design Degree
# Design
# M. Sc.
# Bachelor of Science (BS)
# Bachelor of Business Administration (B.B.A.)
# integrated M.Tech
# MBA, Baker Scholar
# Master of Laws
# Unofficially Audited
# B.Tech + M. Tech
# BME
# Master's degree in philosophy
# Post Graduate Degree
# Dean's List Honors Bachelor of Applied Sciences
# MA / M Eng
# Master's degree in Engineering
# S.B.
# RC
# MSC
# Academic degree
# M,Eng
# B.S.E.E
# BS Mech Eng
# P.G. Diploma
# B. M.
# B.S & B.A.S
# PhD, Building Sci
# Master's degree in English
# E-Lab
# BAcc
# MSc Computer Science
# PGDM / MBA
# Dipl.-Ing.
# B.B.S
# BSc/MSc
# ABD
# BCom
# BPharm
# Certificate of Airline Pilote
# M. Sc
# Certificate, Executive Education
# Master’s Degree
# BA/LLB
# Specialist Degree
# M Eng
# B Eng
# Bachelor of Business Administration (BBA)
# BSEcon
# MSE, BSE
# Program certificate
# D. Phil
# Ph.D - on leave
# BTech
# M.L.I.S
# Physicist
# ECE
# P.G.D.M
# M.M.H
# Bachelor's degree in commerce
# SCPM
# P.G
# Executive Master
# BABA
# Laurea (BA, MS.c)
# Dipl. Ing.
# Management of Information Systems
# MDE Program
# Bachelor of Laws
# MSOD
# CA
# Computer Engineering
# PDG
# Doctor's degree in philosophy
# Master's degree in architecture
# Bachelor's degree in science in engineering
# University Degree
# Postdoctoral associate
# Bachelor’s degree
# Postdoctoral research
# BA and MBA
# specialist
# MSc & D.I.C
# B.tech
# Masters of Commerce
# CSP
# Under Graduate
# Bcom
# BMath
# On Leave
# B.A. w/ Distinction
# MA (Hons)
# B.S. and M.S.
# B.S. in Economics
# B.S. in Engineering
# Pharm.D.
# Certificates
# Bachleor's
# M.A., A.B.D.
# LL.D
# MSFS
# Bachelor of Engineering
# MS (Dropped out)
# B Tech
# Bachelors in Business Administration
# MSci
# B.I.D
# Dipl.-Wirtsch.-Ing.
# B.Ec
# L.LB
# Post-grad
# Bachelor of Medicine, Bachelor of Surgery (M.B.B.S.)
# MCRP
# Chazen MBA exchange
# Grade
# Bachelor in Science with High Honors and Honors in Mathematics
# BA, Business Admin.
# Faculty of Informatics
# Bachelor of Law
# BSA
# BA,LLB
# B.Ap.Sc
# B.Engg
# CAE
# LL.D.
# Ed.D.
# M.Phil. taught
# Electrical Engineering
# Licentiate
# PhD -> MA
# Bachelor of the Arts
# M.Tech.
# Master of Business Administration
# 2:1
# Journalism
# E.M.S.F
# MSM
# PLD
# MBA with distinction
# B.S:
# MSME
# Marketing
# BComm
# BCL
# Master of Business Administration (M.B.A.)
# Masters Engineering
# Bachelors Degree
# BSIE
# Bachelor Of Science
# 1st BSC
# Ms.Sc.
# D. Phil.
# Masters in Business Administration
# MPhil
# Innovation Plus
# B.sc.
# MISM
# MASc
# B.S.E & B.S.Eng
# SB,SM,Sdc
# Post-Doctoral
# Medical Fellow
# Post-Doc
# MS & Phd
# Dr.
# Talpiot B.Sc.
# Law
# BA Magna Cum Laude
# Program for Management Development
# Master of Business Administration (MBA)
# Bachelor of Science - BS
# Master's Degree in Law (LLM)
# BS, MS
# Master of Fine Arts
# Master's of Engineering
# Master of Commerce
# Master in Marketing
# Master of Engineering
# Masters of Science
# PhD,
# B.S. in Business
# juris doctor
# Doctor of Science
# undergraduate
# S.m
# Doctor of Law
# MBI
# Jd
# B.Sc.A
# B.S.`
# Doctor of Medicine
# Bcomm
# BWL
# D.Ec.
# MSBE
# MS CS & Leadership
# M.A.C.C.
# Electronic Engineer
# P.hD.
# BA, MSci
# MIB
# MPPM
# PhD, M.Sc
# Ed.D
# Certificate Program
# [H] B.A.
# Bachelor of Laws (LLB)
# B.Tech & M.Tech
# Bachelor of Technology (B.Tech.)
# BCL & LLB
# MPhil and PhD
# Dr.-Ing
# B.Sc & M.Sc
# B.E & M.E
# Biochemistry
# Ph. D.
# Diplom Wirtschaftsinformatiker
# MA, PhD
# Doctor of Philosophy
# Double Degrees
# Business Admin.
# M.B.B.S.
# Global Executive MBA
# JD Cum Laude
# Psychology
# Bachelor Of Arts
# JD/LLM
# B.SC
# Commerce.
# Juris Doctorate
# Postdoctoral Fellow
# B.A. IP
# CertHE
# Bacehlors
# MBA Module
# Master of Design
# Self
# Product Design
# Accelerator
# BESc Engineering
# Arts
# Postdoc
# Program
# Honors BBA
# Lecturer
# Philosophy Phd
# CEP
# BachelorsEngineering
# SEHD
# Media
# Technical
# B. Sc.
# B. Applied Science
# Masters of ENG
# Non-degree program
# Full Stack
# Bsc Hons
# MA First Class
# Computational CogSci
# BAS + BSE
# BSc First Class
# Specialization
# PR Cert
# Bakk. Rer. Soc. Oec.
# Graduate of Science
# Exchange Programme
# Postgraduate studies
# BSc year abroad
# Exponential Org.
# BA, magna cum laude
# GSP 2012
# Jurid Doctorate
# Batch 9
# Degree in Medicine
# Ina formation
# RTP formation
# M.S.W.
# Grad Professional
# MOOC Molecular Bio
# M.Acc.
# Bachelor of Finance
# B.Engineering
# CFP
# HND with Diplomas
# Residency
# Litentiate
# Bachelor of Arch
# Ex. Juris Doctor
# Master of Divinity
# Board of Dir College
# Hon. B.A.
# Bachelor of Fine Arts
# MS, Ph.D
# BS in Business
# DEUG
# Bachelor´s degree
# Batchelor of Science
# BSEc
# B.Sci.
# M.Sci.
# Social Communication
# BA Banking & Finance
# MBA, Finance
# non-degree
# B.S. Communications
# Bachelor of Sceince
# B,A,
# BS & MSc
# Master of Public Health
# BA Public Management
# Bachelor C. Degree
# Portfolio
# PhD Computer Science
# Music Theory
# Former Student
# MSc EBA
# Bsc Agric
# BSC - acag, arcs
# BSc Hons.
# MS, Social Work
# MS Tech Management
# BS Geological Eng
# MBA & BS.
# Dentistry
# Philosophy Doctor
# Master of Engineerin
# Attorney
# Civil Engineer
# W08
# LLb
# AMP 181
# Non Degree
# Honours B. Commerce
# Research
# Electronics Engineer
# Specialized CERTI
# BS in Social Science
# Bacehlor's
# B.S. & B.A.
# MA.Sc
# Bachalor
# IBA
# DU Fall 2014
# Dipl. Betriebw. FH
# Advanced Engineering
# Individualized
# BA1
# MBA Executive
# Bacherlos in Science
# Business Adm.
# APM
# B.S. Business
# PDL
# IT1, IT2, CCNA,
# No Degree
# Material science
# Arts and Humanities
# PG
# BS and BA
# Sociology
# Ventes
# CAM DIPLOMA
# Part time
# BSocSc
# t-shirt degree
# B.S. and B.A.
# Management Doctorate
# 1st class Masters
# B.A LLB
# B A
# Higher National Dip.
# ecomomics
# IDM DipDM
# Computational
# OM
# Public Relations
# Master's of Arts
# Doctoral Residency
# Ph.D., M.S.
# Art, Design & Media
# Semester Abroad
# bs
# Software
# ba
# Ed. M.
# Political Economics
# Ph.D., M.P.H.
# MS by Research
# Ed. D.
# Post Grad Diploma
# Medical Residency
# Web Dev Bootcamp
# iOS Bootcamp
# A.A.S.
# Architect
# erasmus program
# Bachelor & Master
# AB & AM
# Lawyer degree
# Postgrade
# DESS
# Public Accountant
# Administration
# Independent Honors
# BAppSc
# graduate degree
# Doctor Pharmacy
# Web Programming
# master's degree
# Diplome Ingénieur
# JOSZEF Certificate
# SIFT Certificate
# Accountant
# bachelor of arts
# MD PhD
# Dual MDBSc
# Linguistics
# BS Honours
# BS, Exchange
# btech
# Art
# Master Computer Sc.
# M.A. HSG
# College Dropout
# Executive Programm
# Bachellor
# Informatikassistent
# mba
# Post-doc
# Architecture
# Doctorate Degree
# MA Hons
# Part-time studies
# Graduate Gemologist
# Bachelor, Cum Laude
# B. Eng (Hons)
# Bachelor of Tech.
# Licenciate / MsC
# ICCF
# Engineering & MS
# Bachelors (Hons)
# BA Marketing
# Master in Law
# Bachelor of Manag
# EdM
# EE Profleaders
# BTEC Nat. Diploma
# Master's Engineering
# Bachelor or Arts
# PhD Student
# MBA, MEM, Marketing
# EdD
# Child Welfare
# Executive Global MBA
# Studies
# Msc, IT
# BS, Marketing
# BA, Mathematics
# AAAS
# B.S.c.
# BSE, BA
# Bachelor in Commerce
# History/Economics
# B.A. in Business
# B.A in Political Sci
# Bachelor in Arts
# S. B. Degrees
# Sc.D. Particle Phys.
# B.Sc, PhD
# LLM Tax
# Bachelor, MSc
# AB Liberal Arts
# In progress
# AB - summa cum laude
# BS Computer Science
# MS Computer Science
# Bachelor's Level
# BBusMant
# Under Granduate
# BS, EE & CS
# Bachelore
# BSc (Hons) - 1st
# No degree
# Internal Medicine
# MSCS
# Bachelor of IT
# Athletic Scholarship
# Practical Engineer
# Basic
# Medicina
# Nantucket
# Financial Acc cert
# M.S.E.D
# B. Sc. Degree
# DIC
# Concordia Lutheran
# MA,BA
# MSC Technology
# Economic Development
# Master 2
# Post graduate
# Medical
# MBA (PGSEM)
# Student Exchange
# B Commerce
# BS Tech (Grad Equiv)
# Solution Architect
# MBA (ongoing)
# MA of Human Sciences
# Post-Grad Diploma
# Cross-Registered MIT
# EMFC
# Dr.rer.pol.
# Erasmus
# B.A. (Hons)
# Cryptography
# Msc IT
# Exec Leadership Prgm
# B.S.E.con
# Intl. Human Rights
# Short Courses
# Bachelor's degree in arts with honors
# MBA/MA
# MS, Computer Science
# B. Phil
# Ggraduate
# Post Doc
# MFS
# Masters of Education
# Mellon Fellow
# Certified
# B.A. HSG
# CEMS MIM
# Arts and Sciences
# DM
# M.S.Ed.
# Bachelors and MBA
# MSc Hons
# Post Grad. Diploma
# Postgraduate Studies
# Seminar
# Masters Coursework
# BA Computer Studies
# Math & Com Science
# Orthopedic Surgery
# MSc./Dipl.Kfm.
# Sloan School
# Doctorate-in-laws
# BA,MA,PhD
# BEng (Hons)
# Paralegal
# uncompleted
# Front-end
# Magna Cum Laude
# M.A., B.A.
# Bachlore
# Respiratory Therapy
# Bachelor Education
# Master of Edu
# Honors BA
# GDip HSM
# M.S.A.
# Accredited Diploma
# BED
# MLitt in Management
# Jurisdoctor
# Bsc Business Admin
# Business Comm
# BA/BSE
# Executive Training
# Drs.
# MS, BS
# Post-Grad Global Bus
# Bacherllors
# BA Mathematics
# Multiple
# Minor of my masters
# Professor of Botany
# M.Arch, Architecture
# J.D., Law
# B.A., M.M.
# Master (MBA)
# Phd Candidate
# J.D. (Juris Doctor)
# Chemical Engineer
# Doctor of Law (J.D.)
# JD-MBA
# drs
# Master's Diploma
# Universitario
# MBA, International
# BA, Dual
# Master of science
# MASTER
# B.A. - Mathematics
# Prince2 Practitioner
# State Exams
# Bcom Honours
# Master Thesis
# BACHELORS
# GRADUATE DEGREE
# MSc Architecture
# (BA)
# Network Comms & Mgmt
# 1st Class Honors Bsc
# Graduate School
# B.A. (Honours)
# MS/DOM
# B.S. Finance
# B.B.A. Finance
# Bachelor Fine Arts
# Biomedical Eng
# Doctorate of Science
# Master's research
# Post doc
# MSPC
# M.U.R.P.
# M.Ent
# PPGDM
# B. Engineering
# Professional courses
# BA in Economics
# System Engineer
# WirtschaftinformatiK
# BA & BsEd
# Master of Arts (M.A.
# MBA exchange
# Undergraduation
# BSc(Hons)
# MS-CIS
# MA East Asia
# RLM
# MiM
# CSM
# Mag. rer. soc. oec.
# Finance for Execs
# B.M., B.Ch.
# B.A.(Hons)
# Physics Engineer
# Economic
# PGDBA
# Project Management
# GCS
# Business Law Degree
# Non Completed Degree
# BSc. in Engineering
# Masters of Law
# Business IT
# MS Management / MBA
# DOEACC B Level
# BCOMM
# Master - Engineer
# Diploma of Commerce
# S.Com
# EE BsC
# Post Doctoral Fellow
# Master and Doctorate
# Master and Doctoral
# Extension
# Hon. BSc.
# Master Science
# Winston Fellow
# B.Ed.
# BSc Jt Hns
# Master Grande Ecole
# BSc.(Hons)
# D.Litt
# M.D. and Ph. D.
# Comunicação Social
# Bachler's Degree
# Doctor of Com Scienc
# D.H.L.
# Dr. rer. nat.
# MS Eng.
# Elementary Education
# Grande Ecole program
# Information Science
# EITM
# CSCL
# MBL
# BBibl
# Certificate IV
# Masters Eng.
# MSSW
# BSC. Engineering
# BSC. Information Tec
# BSC. Commerce
# B.Sc. Genetics
# Applied Art
# BSC Computer Science
# Business Advertising
# Bachelor in BA
# LLD
# 1st Class with Hons
# Industrial engineer
# Technical diploma
# BA (Honors)
# Bach. of Commerce
# Bach. of Engineering
# MBA, MPH
# Ph.D, M.Phil, MA
# EM
# Didn't quite make it
# DEA / Postgraduate
# Doctorate degrees
# B.Sc.Hon.
# Ph. D
# Telecom Regulation
# Telecom Engineer.
# BTECH
# Multiple Degrees
# EDSi Fellow
# Certificate in Entrepreneurship
# B.Tech, M.Tech
# Chinese Language
# Ph.D. ,
# French Baccalaureat
# 6th Year
# BBA&MBA
# MBA Exchange Program
# Magister artium
# Exec Program
# BAs
# B.A., Law, Business
# SEP 2014
# MEng & BS
# Ph,D
# Bachelor of Engg
# BSc Electronic Eng
# L.L.B & B.A
# LL.B. & LL.M.
# BS and PhD
# International Mgmt.
# Religion
# C.A.T.
# Bachelor Mathematics
# Law Exempting
# M.SC
# Doctor of Optometry
# Internat. Business
# Diplom Ingenieur
# SJD
# BS Energy Management
# Dr. tech&informatics
# BSc,
# O.D.
# MSc computer science
# MSc(R)
# MS Accounting
# BCIT
# Public Finance
# BSci Engineering
# BA-Hons
# Doctor Of Medicine
# Surgery Intership
# MSc Eng
# LCSW
# B.E. (Hons.)
# Post Graduate Prog.
# M.Sc.,Eng.
# B TECH
# BSEE, MSEE, MSE, MBA
# Fulbright Scholar
# Grauate
# MSHFID
# BSRTIS
# Audio Engineering
# CSE
# residency
# B.A. (Mod.)
# M.S & B.S
# Dentist
# MSj
# EESC
# B.Tec
# BBA/BSc
# HBBA
# Computer
# B.S.Pharm
# MIEE, C.Eng,
# N.C.E
# BIS MM
# Associates,
# Master 2 (M2)
# DoubleMaster'sdegree
# MBA/JD
# AS, BA
# Imaging Science
# Msc,
# Applied Science
# software engineer
# Global Management
# Stanford Ignite 2015
# Marketing BM
# Dual Degrees
# BS Kinesiology
# Full time - Graduate
# B.Tech +M.Tech
# B.Sc (hons)
# bachelors
# M.S & Ph.D
# Cross border M&A
# Int'l Finance
# French Law Superior
# Transnational Law
# BSc (Honours)
# Masters \Metaphysics
# econmics
# Dual degree
# Bchl. of Technology
# M.Eng (Hons)
# PhD & MS
# B.S. magna cum laude
# Animation
# Bachelor Commerce
# Bachelor Bus. Mgmt.
# MSc. Mgmt. of Tech.
# BSc. Computer Eng.
# Bachelor fo Arts,
# Technology studies
# B. Arch.
# M. Arch.
# Bachelor's degree in business administration
# B.S./M.S.
# Master in Business
# MS/BS
# IMF
# Bchelor's Degree
# Legal Doctrine
# Bachelor's of Music
# Business Certificate
# MCHM
# bSc
# Bcom/LLB
# Business engineering
# Part-time
# MSc & PhD
# B.Acc,
# Dipl.
# Dr. rer.nat.
# Programming Tech.
# Business admin
# B. Eng (Electrical)
# J. D.
# ICES
# Bsc (sandwich)
# BBus
# B.Sc. (Hons)
# B of A
# Barcelona and MBA
# Geography
# BS Industrial Design
# BPS
# Hons B. Sc.
# National Diploma
# B.Design
# P.G.Tech
# Doctor of Psychology
# BSs
# Associate of Art
# MSPH
# M.P.S.
# M.S.F.S.
# M.B.BCh
# Diploma Degree
# Maser of Design
# BS Elec Engineering
# Executives màster
# BSE - Unfinished
# Risk Management
# Finance & Economics
# Bachelorship
# PGDPC
# B E
# AB with honors
# BS with Honors
# B.S in Nursing
# Mphil
# PhD in Comp Sc
# MSE in CIS
# MCIT
# MSc in HPC
# MSc (Hons)
# MA & M,Phill
# PostGraduate Diploma
# M.Phys
# ADPA
# B.Des.
# MHP
# Maitrise
# B.C.S.
# Awarded CFA
# Internacional Exc
# MSc Finance
# M.P.P.M.
# MBA Business
# M. Ed.
# MSIE
# Soil Science
# MPA/ID
# IEM
# Letters of Arts
# Accounting and Fince
# LLB & BCom
# B.E.E.
# BVMS
# MVSC
# PGDBM
# BTEC Diploma
# J.D. Law
# ZCPE
# Software Engineer
# PH. D
# O Levels
# DESS Mgnt Accounting
# UnderGrad
# Double degree
# Master MBA
# DESS Banque Finance
# M.Com.
# B.S., M.S, Ph.D.
# BSAD
# Ph.D., M.A.
# Dr. Med.
# M.S.P.
# M.M.C.
# M2
# B.Tech (Hons)
# Culinary Arts
# Building Services
# EPGM
# Masters Degreee
# Technical Sales
# 10+2
# Graduate Business
# 2013 Cohort
# Bachelor’
# B.A. with honors
# Communication
# M Com (Hons)
# BA-honors cum laude
# Negotiation
# BS & AB
# LL.B., Law
# PhD ABD
# Secondary Teaching
# Creative Writing
# M.A. Law & Diplomacy
# MBBS(HONS)
# Post Doc.
# Advanced Mgt Program
# BA, Honors
# MS Taxation
# Masters,
# Music
# MILD
# BA / Diploma (4y)
# Advanced Management
# Master - CEMS
# B.Engg.
# Design in Technology
# Bc
# BA/LL.B
# Bachelor of law
# Bacherlors
# BSc, Ops Research
# ASN
# MEng (Hons)
# Adv.Dip.Screnwriting
# Masters Program
# Post graduation
# VMD
# BBA, BS minor
# Laws
# bachelor degree
# Psychology & History
# Business Strategy
# Higher Diploma
# Master Diploma
# MCHEM
# Dual B.S. w/ Honors
# MARCH
# Technical Engineer
# M.Engg
# M.ENGG.
# HS
# M.A.P.
# CIS
# M.Enng
# BSC HONS
# Promotion
# BAFM
# M. A.
# Dipl. Kaufmann
# Juris Doctor & MBA
# BB
# BA Theatrical
# Highest Honors
# BSc (joint Hons)
# CHT
# Studied
# Science and Business
# Intl Business
# Mas­ter
# +2
# Juris doctor
# BArch.Sc
# Computer engineering
# Bsc - Hons
# Scolarship
# PDP
# Eng.Sc.D
# PMP Designation
# MSc with Honors
# BSc with Honors
# Bachelors / Masters
# A.S
# Information networks
# Masters & Bachelors
# Finance Manager
# B.S. Ed
# Bachelo
# Internatl' Business
# Bachelors of Tech
# Criminal Justice
# Graduat
# Ph.D. (a.b.d.)
# B.S.E & M.S.E
# CMFAS
# Financial Planning
# Winter 2014
# BA Econ (Hons)
# Operations Eng
# PostGraduate
# B.A.S(Hons)
# BMedSci Hons
# LAS
# BS, Ph.D.
# LLB, BA
# Ph
# BA & MA
# Hons. Diploma
# ma
# B.Tech(Hons)
# Master of Dutch Law
# Data Science (MD)
# Charter Program
# MD & Phd
# M Eng Sci
# Diploma Engineering
# Bachelors (4 years)
# MBBS and BSc
# B.A. - L.L.B.
# m.eng
# PhD [submitted]
# Industrial Economics
# MMus
# B.S. in Accounting
# C.A.
# MSIA (MBA)
# Architectural
# Mech Engineering
# LM Degree
# B.Arch(hons)
# BSc Economics
# Health&Wellness
# SB, SM, PhD
# PhD & MSc
# B.S.Mathematics;
# Degree of Commerce
# Bachelor’s Degrees
# YCW14
# BA (hons)
# M.A. (HSG)
# Master of Comp Sci
# BA and MPhil
# Dual Honors BMath
# BMA
# BICT
# BA (Hon)
# Bachelors in Engg
# BS and MEng
# Banker
# Interdis. Program
# Dr. oec.
# Lic. oec.
# One-year course
# Software Engneering
# MBA & MSc
# BT-MT(Dual)
# Post Masters
# MS/EE
# Ingenieur
# Chicano Studies
# Applied Comm
# BMA (exch)
# Agregation
# B.A. and M.A.
# BSc (Honors)
# Business Entreps
# MMM
# M.Mgt.
# Master 1
# journalist
# VWO
# Electrical
# M.S. and B.S.
# CLU
# Broadcast Journalism
# Exchange Period
# M.Sc (B.A.)
# B.A with Honors
# Didn't Finish
# Exec MBA
# B.C.L
# BComm.
# Batcher
# BA - Hons
# Bachelor and Master
# ABM’s B-to-B
# Double major
# MBA & Undergraduate
# Engineering AS
# Master's, Bachelor's
# B.S. and B.A.S
# M.Litt
# M.B.S
# Social Science
# Master (1st Class)
# BS Finance
# Internet Marketing
# B.A., cum laude
# GSP!#
# Bachelor of Eng
# M.H.A.
# PostDoc
# Economics Dip
# Licentiate degree
# MA 1st Class Honours
# Electronic engineer
# Digital Media Design
# Bsc. ( Hons. )
# MEng &Man
# certificate
# LL.M.Eur.
# (B.B.A.)
# (M.B.A.)
# Grad
# B.T
# M.T
# B.Admin
# BS Econ, BAS
# Student
# Associate In Arts
# AB1
# AB2
# MS, EE
# High school degree
# m.Sc.
# Management Science
# B.A. Business
# B.E.(Hons)
# Masters in Fin Mgmt
# B.Tech and M.Tech
# GSMP
# MBA/MEM
# Bach.
# CCRP
# BS Cum Laude
# Surgery Residency
# B.S. Aerospace Eng
# B. Phil.
# Full time MBA
# Graduate programme
# BS Comp. Engineering
# 2.1
# CS Education Fellows
# B.A., Communications
# Eng.
# PHD, MS
# Doctor Rerum
# Informatics / CS
# Telecoms and Digital
# M.s
# AB Economics
# J.D./L.L.M.
# BSc and MSc
# M.A. and Ph.D.
# M.L.S.
# CSPO
# B.Bus.Sc.
# B.Ec.
# Exec. Certificate
# Accelerated
# 1 Course
# ab
# Stanford Ignite
# EART
# Educational Studies
# Bachelor's Degre
# ---
# Master Of Science
# PgD
# MTL
# LLM Int'l Comp Law
# B.E (Hons)
# Graduação
# Gestão Empresarial
# Faculty of Law
# BSIB
# Senior Residency
# Intl. Management
# Doctor of Bus. Admin
# B.Eng. & Mgt.
# PhD E.E.
# College Degree
# Course Certificate
# Bachelor´s
# Class President
# MS and PhD
# DrPH
# GCSE
# CSTN
# BS - Accounting
# B.A.H.
# Int. Business
# Associate design
# Bachelor.I.T
# (BEng Hons)
# (MSc)
# A Levels
# Informatic
# Concentration
# B.A.A.
# Info Tech Program
# BSC Business Admin.
# Oncology Fellow
# BSc Honours
# ARCBS
# European Business
# MSAE
# IC
# JD, Magna Cum Laude
# Cert. Res. Appraiser
# Executive education
# Medical Doctor (MD)
# Economia Aziendale
# Classical Diploma
# Bachelor of Medicine
# Bachelor of Surgery
# Echols scholar
# Certified Orthotist
# MBA/MS
# Focused Program
# BS in Bus. Admin.
# Masters in Economics
# Bachellor of Science
# Certficate
# B.A. Honors
# Independent Study
# Post. Grad Diploma
# Applicable Math
# Hon's
# Computing (Hons)
# M.B.T.
# MD.
# Finance & Accounting
# Programmer
# ABB
# MA, M. Philosophy
# ADP 61
# B.Sc. & PhD
# Meng
# Bachelor of Property
# Business Honors
# M.Sc.Eng.
# BA (Media Comm)
# BFA and BA
# Graduate Coursework
# B.S. program
# B.A. program
# Dipl.-Ing.-ETH
# PgDip
# C.Sc
# Global Studies
# MS(MBA)
# B.A. Degree
# Bach, Liberal Arts
# Eric Ries
# MRED
# collage
# Bachelor of Mgmt
# BEng, 1st Class
# Fellowship, 2009
# M.P.H. and D.Ph.
# B.S. Management
# Bacholars Degree
# bachelor of engineer
# Spanish
# CEng
# BSc / MSc Hons
# M.Sc.Tech
# bsc
# bachlor degree
# BA & PhD
# C
# BBachelor of Science
# Data Science
# D.Sc.h.c.
# BSci
# Bachelor Honours
# BA, B.Comm
# Be
# FDA Textiles Fashion
# MD (MBBS)
# Cleared Level 3
# Bsc.ICT
# E MBA
# M.B.B.S, M.D
# Social Graph
# BA Business
# 'A' and 'O' Level
# Ingegneria
# Batchelor's Degree
# BSc Eng
# B.Math.
# Bachiller
# CAIA Charter
# Mechanical Engg
# ITP
# Computation Arts
# Master Management
# Visiting Graduate
# Executive MBA Module
# Management Module
# PostG BusinessSchool
# BS in Communication
# B.Sc.(Hons)
# Directors Education
# Professional Studies
# MSTC
# Masters of Engineering
# RDS-UCD
# BA (Hons).
# Post-graduate degree
# Dipl-Ing
# Masters M.S
# BsC Engineering
# MsC in Finance
# BCom.
# BS, BAS
# BA and Masters
# Executive Scholar
# MGA
# P.M.D
# ATACP
# BSc and Phd
# Health Care
# Diplomacy
# Post-Doctoral Fellow
# Broker license
# Reaserch Program
# Certified Technician
# Residency/Fellowship
# B.S. / M.S.
# Philosophy-Economics
# Expert
# Bachelors of Applied Science
# Master of Eng'g
# B.ME
# Politics
# MCCE
# account
# BsD
# CAPAES
# Therapies
# Dipl-Ing.
# H.BSc
# MB BS
# M.s.c
# Joint Master
# B.s.c.
# C.A
# U.S. CPA
# B.A.(LLB)
# Engineer’s Degree
# Pricing for Profit
# BEng(1st Class Hon.)
# MA/BA
# Masters (Hons)
# Extension School
# CPA, CA
# ICD. D.
# Dental degree
# MTPO
# B.Studio Arts
# BA & JD
# BE.hons
# Private Equity and Venture Capital
# Architectute
# Master of Sciences
# Bcom.
# BASc.
# BscHons
# Bacaharel
# B. Ed.
# Dual(B.Tech.+M.Tech)
# Develop Software
# MS in Technology
# BS in Computer Engineering
# Interdisciplinary
# Teaching Certificate
# M.Sc Eng
# B.B.M
# Part of PhD
# Electrical Engg
# Pre-Law
# BTEC N.D.
# B. E.
# Full time
# GSP14
# Senior Consultant
# BA - Accounts
# Master of Science (Supply Chain Management)
# Hotel Mgmt Degree
# Lawyer
# B.C.L.
# School of Business
# MA, Trinity College
# Beng
# Juris Doctor degree
# Doctorate, J.D.
# Licenza
# JD Law
# BS (with Honors)
# International Rel
# Latin Studies
# FinancialRiskManager
# Bachelor Dgree
# -
# McIntire School
# A-Level
# Honors BS
# B.S.M.
# BJMC
# BA(Honours)
# UXID
# B.MSc.
# TGMP6
# Child Psychiatry
# Psychiatry
# Google Certified
# B.A.LLB
# Posgrado
# BS Corporate Finance
# B.Com (Honors)
# Master of the Arts
# BE/BS
# M.S Business Admin.
# MPharm Pharmacy
# Masters (MSc)
# Double Masters
# Master (Dipl.-Ing.)
# advanced mgmt prgm
# Leave of Absence
# Go2Market Program
# MSc. E.E. Eng. (Ir)
# Double Degrees; Master
# Economist
# SAPM
# Business-Economics
# BTEC National Dip.
# HEC Business studies
# Uundergraduate
# B.A. Honours
# BBA Bachelor
# Diseñadora Gráfica
# J.D., M.L.I.S, B.A.s
# Electr. Engineering
# ACSM-CPT
# Mastere
# Bsc. Eng.
# H.B.Sc.
# Preparatory School
# BHMS
# Public Affairs
# B.A .
# B.Int.Bus
# Specialist studies
# MS&E and Philosophy
# BA, Valedictorian
# Teacher's Certif.
# Sport Degree
# Intermediate
# 2 year
# Ph.D./MS/BS
# A. B.
# MMA Cert. (Tier 1)
# MusB (Hons)
# University & Master
# Bachelor's Degree,
# Membership
# B.A., M.A.
# Bach. of Technology
# M.COM.
# B.Sc. (1st Cls. Hn.)
# Post-graduation
# BAJMC
# Master in Public Administration in International Development
# BS / BA
# Master in Sciences
# B.Eng. (Incomplete)
# Master's in Finance
# MBA / MSA
# Vocational School
# Bachelor of Economics
# Diplom-Kaufmann/ MBA
# Graduate Education
# Performing Arts
# General Mgmt ADP
# Ceritified Course
# Certified Course
# B.Tech./M.Tech.
# B.SC. (Hons)
# Never Finished
# National Security
# BSC Hons
# Doctorates
# Graduate coursework
# MPhil and DPhil
# Certificate,
# BSE w/ high honors
# Immersive
# M.A., Education
# MS, PhD
# M.A., education
# Entreprenuership
# Fellowship, Econ
# B.S. Architecture
# economics
# B.S. (partial)
# Batchelor
# Award School
# M.Eng.Sc.
# MBBS, MS, DNB,
# Master equivalent
# B.Com. Hons
# Programme in
# MBA/PGDLL
# B.A. Hon; M.A,
# Phil.M.
# B.Env.
# B.A.L.L.B
# Honour Bachelors
# Ecole Superieure
# BSc Arch
# MD, CM
# General Surgery
# Plastic Surgery
# ...
# Business & Financial Modeling
# Asset Management
# Investment Management Level -1 & 2
# Business & Statistics Analysis
# 2 Year Enrollment with Transfer
# PhD ME, MA Math, BS ME
# Doctor of Philosophy (PhD) Materials Science & Engineering
# Master's degree Nanoscience
# Master's degree Nanotechnology
# BA & MS Mechanical Engineering
# Business Management, Marketing
# Doctor of Philosophy (PhD) Physics
# Bachelor's degree Physics and History
# Doctor of Medicine - MD Medicine
# Doctor of Philosophy (Ph.D.) Pharmacology
# bachelor’s degree in Water Science
# BA Economics, Chemistry
# Master of Business Administration (M.B.A.) Finance
# yes
# BS in Microbiology
# Masters of Science in Chemistry
# M.Sc.Artificial Intelligence
# MS E&CE
# MS / MBA
# master’s and Ph.D
# master of Science
# Master Applied Economics
# Doctor of Medicine- MD
# Associate of Arts and Sciences - AAS
# Ph.D, MS
# BS/ MS/ PhD
# Ph.D. (Dr. Sc. Techn.)
# Community Health Education
# Blue Ocean Strategy MBA
# Bachelor of Accounting (Hons)
# Master of City and Regional Planning
# Postdoctoral Research Associate
# HDR
# B.com.(H)
# Academic
# M. S. Chemical Engineering
# B. S. Chemical Engineering
# MA,
# Doctoral Minor in High Performance Computing
# Paramedic Certificate
# Clinical Internship
# MS,PhD
# Masters Business Administration -MBA
# Master of Engineering -
# BE, MS
# BS (Interdisciplinary)
# BALAField Of StudyInterdisciplinary Studies (Philosophy/Psychology)
# BA, MA, PhD
# Bachelor of Pharmacy - BPharm
# Postgraduate certificate
# Bachelor of Arts, Silver Honors
# M.V.Sc.
# Postdoctoral training
# Pharm.D., Ph.D
# Lean Six Sigma Green Belt
# Alcohol and Addiction Studies
# MS & Ed.S
# Master in Mental Health Counseling
# Business Sch Minor
# HND (Associate Degree)
# IUT SRC
# Master's degree (Visiting student)
# Uncompleted Bachelor's degree
# Honors - Double Major & Minor
# BTech (Engineering)
# MBA, MENG
# MSc in Mathematics
# B.Tech + M.Tech (Dual Degree)
# Autodidact
# MSc Management Information Systems
# B.A., Mathematics
# B.Tech (Computer Science & Engineering
# Masters in Business & Management
# PhD in Mechanical & Mechatronics Engineering
# BASc in Engineering Science
# MA in law
# BSc Multimedia Technologies and Design
# Alumnus
# Energy Innovation and Emerging Technologies Certificate
# B.I
# Bachler of Engineering
# Masters in Applied Finance
# DPT
# B.S. Information System Security
# B.Eng (Petroleum Engineering)
# International Company Directors course
# LL.B., LL.M.
# Executive Leadership Program by BTG Pactual
# Board Digital Program, Innovation Acceleration
# Licenciada en Economia
# Bachelor of Sciende
# VCE
# M.A. with Honors
# HSE Diploma at 16
# Executive Master of Business Administration (Executive MBA) in Marketing
# Business Analytics
# Jornalismo
# B.S. exchange
# I.T. Networking
# Higher education
# Associates Degreee
# Licenciado en Administración
# Small And Medium Business Administration Specialization
# Master’s degree in international relations
# M.L.A.
# Ms. Mathematics
# Specialised Master's degree
# Master Degree in Civil Engineering, Telecommunication
# Electrical Engineering (B.S.)
# Research Professor / Instructor
# Computer Science (Bioinformatics) (Ph.D.)
# Master's of Design Innovation
# Master's degree in Biotechnology
# Ph.D. in Bioinformatics
# Studies Architecture
# MSc + BSc
# Finance management
# Bachelors in Computer Applications
# Ph.D. in Biomedical Engineering
# Ph.D., Business Studies
# Master of Health Informatics, Health information
# School of Continuing Education, Environmental Management
# Technical Analysis Course (TAC)
# Design Management MSc
# Industrial Engineering MSc
# Industrial Engineering MSc (Erasmus Programme)
# Electrical Engineering BSc
# Master's degree in Kinesiology
# Finance, General
# B.S, Business Administration
# MD,
# M.S. in Integrated Marketing Communications
# Impact Investing Programme (pending)
# B Engineering
# Visiting Researcher, Robotics
# Doctoral Researcher, Micro- and Nanotechnology for Environmental Remediation
# Entrepreneurship Essentials, Emprendimiento/Estudios sobre emprendimiento
# Mass Communication/Media Studies
# Completed 3 of 4 years of B.S.
# Field-Placement Program
# Master of Social Work - MSW
# Pulmonary, Critical Care and Sleep Medicine
# Sustainable Business
# Bachelor of science (B.Sc.)
# Bachelors of Science Degree
# Bacherlor's degree
# MIT + Entrepreneurs Organization Master
# M.T.M.
# Master of Science (Msc.),
# Bachelors of Technology (B.Tech.)
# B.Eng. (Hons.)
# B.A.Sc (Hons)
# Forcht Centre of Entreprenuership
# bS
# Senior Fellow
# Masters of Applied Finance
# Matric (Computer Science)
# manufacturing system engineering
# MA Mathematics in economics
# Business Information Technology , Dip, CISSP
# AB Government
# PGDip in Marketing
# MSc. in Economics
# BTch
# Master in Science (MSci)
# Community Family Medicine Residency Program
# Masters in Global Marketing Management
# B. Mechanical Technology
# Product Design/Engineering
# PhD / Dr.-Ing.
# Doctor of Law (J.D)
# Bachelor's degree p
# B.F.A. Interactive Design & Game Development
# BSc (H)
# M.S.Software Systems
# BA Ancient History & Classical Archaeology
# MSC Innovation, Entreprenership & Management
# BA Archaeology and Anthropology
# General Surgery Internship, General Surgery
# Spine Fellowship, Adult Spinal Disorders
# Orthopaedic Residency, Orthopaedics
# Bachelor of Business Administration in Hotel Management
# B.S., B.A, Minor
# MSc & Diplôme de grande Ecole
# B. F. A.
# Bachelor’s Degree in Architecture
# Master's Degree in Business Administration - MBA
# Bachelor, Business
# Master, Engineering
# Reuters Executive Management Training
# BS(hons)
# Bachelor - Law
# Black Venture Institute
# Ph.D. oec. (HSG)
# B.Sc in Filmmaking
# AGS
# BCHE
# MA in Marketing
# Grad. Dip. Management
# VCEP
# SSLC
# Post Baccalaureate Diploma (Graduate Diploma)
# Doctor of Business Administration (DBA)
# Master of Project Management (MPM)
# Business Administration in Management (BBA)
# Graduate Certificate in Internet
# Entrepreneurship & Management
# AS General Studies
# Graduate classes
# B.S.C (Hons)
# Diplom-Betriebswirt and Bachelor of Arts
# MSc Business Administration & MSc Computer Science
# MSc Business Administration | Digital Business
# MSc. EBA
# Executive Program (EP)
# BCom / HD-U
# BSC(c)
# MLA, Management
# Quantitative Finance (CQF)
# MBA (candidate)
# Executive Level Courses Completed
# Master in Operations Management
# Mechanical Industrial Civil Engineer
# Master in Tax Management
# Dipl.Ing. (FH)
# BoE
# Lila Acheson Wallace Playwriting Degree
# Doctor of Science in Economics
# Master (Drop out)
# Licence (BBA)
# FCCA
# Professional Development Certificate
# BSc, PhD, MD
# BA (Currently on Leave of Absence)
# Certificate in Corporate Finance
# artificial intelligence
# High Scool
# LL. B.
# B. Com with hons.
# International Management Asia
# Year-long Abroad Program
# Master Computer Science
# bachelor in Science
# bachelor in science
# Master in Public Health
# BCS Computer Science
# Physics and Engineering
# Bcom Hons
# B.S. OT
# M.S.S,
# M.L.S.P.
# Post-PhD
# PhD sub-speciality
# Bachelor of Science, Business Administration, Management Information Systems
# Doctor of Philosophy - PhDField Of StudyAerospace
# MSNE
# BSNE
# Dual Masters Degree
# Executive Education - Finance, General
# Executive Education, Specialization
# Bachelor of Science in Foreign Service
# BBS,
# Tourism and Marketing
# PhD - unfinished
# Technology Program
# M.A.Sc, B.A.Sc
# BSc. (Hons.)
# Technical Certification
# Lic
# BA (mod)
# Certification of PKI
# Bachelor of International Finance
# Master of Industrial and Labor Relations (MILR), Human Resources and Organizations
# Certificate (in progress)
# B/M.Eng.
# Bachelor & Master's
# Computer Engineering Certification
# programmer
# PhD in Medical informatics
# MTCP
# M.Sc (Economics)
# Licence Degree
# Clinical Fellow
# MBA - Economic War School
# Eksportingeniør
# Examination
# B.S.C and M.S.C
# BA, Political Science and International Affairs
# Licence Économie
# Degree in Law and Society
# Software Architect
# Masters in International Mgmt.
# Certificate SEP
# BCom,BA
# Columbia Engineering Coding Bootcamp
# Landscape Architecture
# MDESIGN
# aviation honors
# Postdoctoral scholar
# Dip Exp
# Masters of Appiled Positive Pschology
# Masters in BM
# Mdiploma
# Bachelor and Advanced Master's Degree
# Advanced Master's Degree
# Appreciation of Song Picturisation in Indian Cinema
# Film Appreciation
# Bachelor of Economics and Business Administration
# Student Diploma
# Preparatory Classes for National Competitive entrance exams to leading
# 6.002x
# Executive Educaiton
# Bachelor of Physiotherapy
# BE - MBA
# Master of Public health
# Bachelor of Homeopathic Medicine and Surgery
# Master of science(Msc)
# Masters of computer science
# BRSS
# BSEE,MSEE
# Bsci
# B.S Computer Science
# B.A. of Arts
# HIgher Diploma in Accounting
# Advanced Private Equity and Venture Capital Programme
# DEUG A
# B.Sc in Engineering
# ISE
# Bcomm Economic and Management Sciences (Hons)
# Innovation & Growth - Executive Program
# Bachelors of DEsign
# Full Stack Engineering Certificate with 525 Clock Hours
# BBA International Business, Entrepreneurship, Asian Business and Society, Asian Studies
# Bachelors of Business Administration (BBA)
# Doctorate of Nursing Practice
# Diploma in Computing
# b.com
# MITM
# International Foundation
# Expertise
# Master of Science - M.S
# Grad Certificate
# PM&R residency
# Medicine Internship
# Bachelor of Arts - B.A.
# Master of Science - M.S.
# Bachelor's Degree of Economics
# Bristish Masteer Degree in Computer Science
# Bachelor of Arts (B.A.) Field Of Study Environmental Studies and Public Policy Studies
# PhD, Doctor of Philosophy
# Certificate in Management Studies
# Master's of Sustainable Transportation
# B.S. E-Consumer Studies
# Bachelor's Degree, 1st Class Honours
# MBA, B.Eng., Sc.
# DCP
# B.S. Creative Writing
# B. tech.
# MBA (Euro*MBA program)
# Entrepreneur-in-Residence
# Masters in Engineering Management
# ALM degree candidate
# BA mass communication & journalism
# Program on Negotiation
# Post grad certificate
# One year program
# MsC Industrial Engineering
# PhD/DIC
# BLaw
# AAT
# 12th Standards
# ICAC
# Micro-Master

# %%
import regex as re

# %%
test_word = 'hdahda@#%dad889'
new_word = re.sub('[^A-Za-z]+', '', test_word)
new_word
# Out:
# 'hdahdadad'

# %%
#classify degree type by one hot encode for diploma,bachelor, masters, and phd
is_bachelor = list ()
is_master = list ()
is_phd = list ()
for deg in list (deg_df_v2.degree_type):
    #deg = str(deg).replace('.','').lower()
    deg = re.sub('[^A-Za-z]+', '', str(deg).lower())
    if deg[0] == 'b': #'bachelor' in deg or 
        is_bachelor.append (1)
    else:
        is_bachelor.append(0)
    if 'phd' in deg or 'doctor' in deg:
        is_phd.append(1)
    else:
        is_phd.append(0)

deg_df_v2['is_bachelor'] = is_bachelor
deg_df_v2['is_phd'] = is_phd
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-252-bdd69d78749f> in <module>
#       6     #deg = str(deg).replace('.','').lower()
#       7     deg = re.sub('[^A-Za-z]+', '', str(deg).lower())
# ----> 8     if deg[0] == 'b': #'bachelor' in deg or
#       9         is_bachelor.append (1)
#      10     else:
#
# IndexError: string index out of range

# %%
is_bachelor = list ()
deg_mod_list = list()
deg_list = list (deg_df_v2.degree_type)
for deg in deg_list:
    deg = re.sub('[^A-Za-z]+', '', str(deg).lower())
    deg_mod_list.append(deg)
    if deg == '':
        is_bachelor.append(0)
    elif deg[0] == 'b': #'bachelor' in deg or 
        is_bachelor.append (1)
    else:
        is_bachelor.append(0)

# %%
deg_list[len(deg_mod_list)-1]
# Out:
# nan

# %%
deg_mod_list[-1]
# Out:
# 'nan'

# %%
deg_df_v2[deg_df_v2.is_phd == 1]
# Out:
#                                     deg_uuid  \
# 12      01cdac9d-4c44-d8b1-3acc-ec666be88269
# 26      282de5b4-3b72-ffcb-2a9c-e4e100f2b30e
# 37      d89f6c52-eb92-2c74-b2d1-3f8a4cb0ed7b
# 54      e13ad498-11af-ea5a-eb34-18a243257d72
# 72      ccacbd2f-177c-22d6-7457-c088447a9352
# ...                                      ...
# 369461  869ff8ac-2f64-4108-b68e-4aaaf11b620a
# 369466  417c2684-f4da-4193-afb4-147e9c2db2e2
# 369478  bf2c5d23-714c-4075-ac8e-d778867a055a
# 369495  4f3af956-73dd-4df4-bfc2-ead7968bd6f2
# 369504  bec1bb6c-a0f4-4ce9-947c-e5158d32c64f
#
#                                                  deg_name  \
# 12                    Ph.D  Finance @ Tel Aviv University
# 26      Ph.D  Electrical Engineering @ University of M...
# 37       Ph.D  Computer Science @ Northwestern University
# 54      Ph.D  Theoretical Physics @ Moscow State Unive...
# 72          Ph.D  Physics @ Weizmann Institute of Science
# ...                                                   ...
# 369461  PhD  Industrial Engineering (Logistics Track) ...
# 369466  PhD/DIC  Mechanical Engineering/Computer-aided...
# 369478  Ph.D.  Clinical Psychology @ University of Cal...
# 369495  Doctor of Philosophy  Bioengineering and Biome...
# 369504  PhD  Materials Science and Climate Change @ Un...
#
#                                  people_uuid                person_name  \
# 12      080271bd-1a07-aeea-e587-34c01d9de5bb                  Gal Cohen
# 26      34cf05a8-2882-3054-2e4f-58cfb3e886c6            James M. Butler
# 37      596487d5-0310-667f-998f-8612b64483de             Monica Barback
# 54      c4a20242-8739-09ef-732f-89674b664083             Pavel Vorobiev
# 72      d1e34ead-8b92-5a1a-393e-4c30501e8b36           Guy Levy-Yurista
# ...                                      ...                        ...
# 369461  be10b5e8-1806-4f30-ab06-4a2dcd535b4d                 Moin Islam
# 369466  117a0e09-0609-4945-846d-df1a133d87c3            Yoon Seok Chang
# 369478  0c16ce09-4a4e-47e0-9dab-f3fcccf85101              Alissa Pencer
# 369495  d06466ba-065f-488e-bf85-753133c839d9              Mohsen Afshar
# 369504  d36328de-6daa-433f-8fe0-0bf36f0d2c62  Gabrielle Bourret-Sicotte
#
#                             institution_uuid                 institution_name  \
# 12      e3a55987-fdbb-cb79-fcb2-7261461b43a5              Tel Aviv University
# 26      4c942c9c-88f1-65fc-0caf-ea1566d06ef7           University of Maryland
# 37      f23fd798-2cc4-426e-c670-13e81ba24806          Northwestern University
# 54      6c7f7d63-3950-a6b1-3b02-d15d0f0e93dd          Moscow State University
# 72      441d1da0-fe67-f247-8dc6-3adccfc09a34    Weizmann Institute of Science
# ...                                      ...                              ...
# 369461  e9fc6d99-a968-c8e2-549e-ee6e13b9127f  Georgia Institute of Technology
# 369466  3e893a4c-f191-b42c-5dab-4785e07d3c75          Imperial College London
# 369478  92eb706d-9f82-53b1-da8e-faaebc06a2fa            University of Calgary
# 369495  29cc430b-aa60-6f52-a62f-34805e3b848f            University of Toronto
# 369504  ec74a4ae-156b-5cba-82be-7922964ca376             University of Oxford
#
#                  degree_type  \
# 12                      Ph.D
# 26                      Ph.D
# 37                      Ph.D
# 54                      Ph.D
# 72                      Ph.D
# ...                      ...
# 369461                   PhD
# 369466               PhD/DIC
# 369478                 Ph.D.
# 369495  Doctor of Philosophy
# 369504                   PhD
#
#                                                   subject  started_on  \
# 12                                                Finance         NaN
# 26                                 Electrical Engineering         NaN
# 37                                       Computer Science         NaN
# 54                                    Theoretical Physics         NaN
# 72                                                Physics         NaN
# ...                                                   ...         ...
# 369461           Industrial Engineering (Logistics Track)         NaN
# 369466  Mechanical Engineering/Computer-aided Systems ...         NaN
# 369478                                Clinical Psychology  1998-01-01
# 369495          Bioengineering and Biomedical Engineering  2013-01-01
# 369504               Materials Science and Climate Change  2015-01-01
#
#        completed_on  is_completed  is_bachelor  is_phd
# 12       1999-01-01          True            0       1
# 26       1990-01-01          True            0       1
# 37              NaN         False            0       1
# 54              NaN         False            0       1
# 72       2002-01-01          True            0       1
# ...             ...           ...          ...     ...
# 369461          NaN         False            0       1
# 369466          NaN         False            0       1
# 369478   2004-01-01          True            0       1
# 369495   2019-01-01          True            0       1
# 369504   2019-01-01          True            0       1
#
# [21735 rows x 13 columns]

# %%
deg_df_v2.isnull().sum(axis=0)
# Out:
# deg_uuid                 0
# deg_name             30043
# people_uuid              0
# person_name              0
# institution_uuid         0
# institution_name         0
# degree_type          11767
# subject              27049
# started_on          221885
# completed_on        169164
# is_completed             0
# dtype: int64

# %%
#merge deg_df with main_people_df
main_people_df_v2 = pd.merge(main_people_df_v1,
                            deg_df_v2,
                            on='people_uuid',
                            how='left')

# %%
main_people_df_v2.columns
# Out:
# Index(['people_uuid', 'name', 'first_name', 'last_name', 'gender',
#        'country_code', 'state_code', 'region', 'city', 'org_uuid',
#        'featured_job_organization_name', 'featured_job_title', 'facebook_url',
#        'linkedin_url', 'twitter_url', 'logo_url', 'description', 'deg_uuid',
#        'deg_name', 'person_name', 'institution_uuid', 'institution_name',
#        'degree_type', 'subject', 'started_on', 'completed_on', 'is_completed'],
#       dtype='object')

# %%
len(main_people_df_v1)
# Out:
# 1099621

# %%
len(main_people_df_v2)
# Out:
# 1197872

# %%
main_people_df_v2[main_people_df_v2.duplicated(subset=['people_uuid'])]
# Out:
#                                   people_uuid             name first_name  \
# 1        ed13cd36-fe2b-3707-197b-0c2d56e37a71      Ben Elowitz        Ben
# 3        5ceca97b-493c-1446-6249-5aaa33464763   Kevin Flaherty      Kevin
# 19       f7e8c40f-c146-cf63-65f2-9e292c0d2323       Peter Pham      Peter
# 24       ea9f4980-600c-84f4-a5d6-b4f8c2f787fb          Gus Tai        Gus
# 25       ea9f4980-600c-84f4-a5d6-b4f8c2f787fb          Gus Tai        Gus
# ...                                       ...              ...        ...
# 1197597  112e2012-a76d-4dbd-8389-19fc8f1ccf01     Todd Follett       Todd
# 1197759  6e5c180b-e432-429e-b7c1-215f41a5526a  Cizar B. BRAHIM   Cizar B.
# 1197760  6e5c180b-e432-429e-b7c1-215f41a5526a  Cizar B. BRAHIM   Cizar B.
# 1197806  09ac1f47-e230-4a21-b7b9-03ed51aed9cd        Frank Lai      Frank
# 1197816  267cd3aa-a22c-47fd-948f-00c3c29eb066      Ian Conyers        Ian
#
#         last_name gender country_code state_code         region  \
# 1         Elowitz   male          USA         WA     Washington
# 3        Flaherty   male          NaN        NaN            NaN
# 19           Pham   male          USA         CA     California
# 24            Tai   male          USA         CA     California
# 25            Tai   male          USA         CA     California
# ...           ...    ...          ...        ...            ...
# 1197597   Follett   male          USA         MA  Massachusetts
# 1197759    BRAHIM    NaN          SWE        NaN            NaN
# 1197760    BRAHIM    NaN          SWE        NaN            NaN
# 1197806       Lai   male          NaN        NaN            NaN
# 1197816   Conyers   male          USA        NaN            NaN
#
#                     city                              org_uuid  ...  \
# 1                Seattle  cf253887-5eac-21a2-28d3-47db7311f7e9  ...
# 3                    NaN  789e5e4d-0c90-d06e-92a0-b800b461c3da  ...
# 19       Manhattan Beach  f1ebf335-96d6-edaf-0b45-55ce87fd1891  ...
# 24            Menlo Park  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9  ...
# 25            Menlo Park  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9  ...
# ...                  ...                                   ...  ...
# 1197597           Easton                                   NaN  ...
# 1197759              NaN                                   NaN  ...
# 1197760              NaN                                   NaN  ...
# 1197806              NaN                                   NaN  ...
# 1197816              NaN                                   NaN  ...
#
#                                      deg_uuid  \
# 1        be3b1fce-5a88-0cc7-ffe3-0908d273e69a
# 3        7aaaa052-0b81-81aa-3ff8-17f59fcb707e
# 19       4ec3b624-cc96-46e0-881c-9b7147d0aacc
# 24       5b23ce81-00b9-2cd4-7c10-44fc40f386dc
# 25       7de82453-2ffe-a818-9f29-11c71e5496f5
# ...                                       ...
# 1197597  078ed065-3570-4137-ab06-27aa204c327a
# 1197759  94495f07-9b4e-4df6-b629-9e4b3f24cdb9
# 1197760  76c22757-95df-4d44-9dad-95772a08d238
# 1197806  739519dc-ee80-4d86-af0e-eb7e8e4d0fc4
# 1197816  cc5b4e8f-53a8-4093-8f33-07c0bd10ca2e
#
#                                                   deg_name      person_name  \
# 1        BS  Applied Mathematics @ University of Califo...      Ben Elowitz
# 3                        MBA  unknown @ Indiana University   Kevin Flaherty
# 19                                                     NaN       Peter Pham
# 24            BA  Applied Mathematics @ Harvard University          Gus Tai
# 25         MBA  unknown @ MIT - Sloan School of Management          Gus Tai
# ...                                                    ...              ...
# 1197597  Master’s Degree  Creative Writing @ University...     Todd Follett
# 1197759  Micro-Master  Manufacturing and SupplyChain Ma...  Cizar B. BRAHIM
# 1197760  Master  Management and Entrepreneurship @ Univ...  Cizar B. BRAHIM
# 1197806  BEng  Electrical Engineering @ The Hong Kong P...        Frank Lai
# 1197816  MA  Urban and Regional Planning @ Georgetown U...      Ian Conyers
#
#                              institution_uuid  \
# 1        10f9a25b-9675-2281-486e-a52955c706df
# 3        3b4faff0-708e-8c1c-83f0-6fea01016519
# 19       7c93ee09-edee-68a9-41e7-3d924dfda730
# 24       d8b57c0e-9f0f-4dcb-d207-a12a90c64a2d
# 25       b052eecd-4c29-c1c6-3157-591011af2a0c
# ...                                       ...
# 1197597  2a24e1a4-52f2-7c4e-165a-b8817b43d1e7
# 1197759  633f2fde-1942-a747-d03b-7af01d873206
# 1197760  ff60def2-50a7-2188-4001-02f9f51c9ff5
# 1197806  06d28148-ea46-ab42-b4fa-e7b6db2fd850
# 1197816  f930a702-4e4b-810d-dbe6-11569a939112
#
#                              institution_name      degree_type  \
# 1          University of California, Berkeley               BS
# 3                          Indiana University              MBA
# 19           University of California, Irvine              NaN
# 24                         Harvard University               BA
# 25           MIT - Sloan School of Management              MBA
# ...                                       ...              ...
# 1197597           University of San Francisco  Master’s Degree
# 1197759      MIT School of Distance Education     Micro-Master
# 1197760                University of Bordeaux           Master
# 1197806  The Hong Kong Polytechnic University             BEng
# 1197816                 Georgetown University               MA
#
#                                           subject  started_on completed_on  \
# 1                             Applied Mathematics         NaN   1994-01-01
# 3                                         unknown         NaN          NaN
# 19                                        Biology         NaN          NaN
# 24                            Applied Mathematics         NaN          NaN
# 25                                        unknown         NaN          NaN
# ...                                           ...         ...          ...
# 1197597                          Creative Writing  2014-01-01   2016-01-01
# 1197759  Manufacturing and SupplyChain Management  2020-01-02   2021-05-16
# 1197760           Management and Entrepreneurship  2010-01-04   2012-05-05
# 1197806                    Electrical Engineering  1997-09-01   2000-06-01
# 1197816               Urban and Regional Planning         NaN          NaN
#
#         is_completed
# 1               True
# 3              False
# 19             False
# 24             False
# 25             False
# ...              ...
# 1197597         True
# 1197759        False
# 1197760         True
# 1197806         True
# 1197816        False
#
# [98251 rows x 27 columns]

# %% [markdown]
# # Jobs

# %%
#import jobs.csv
jobs_df = pd.read_csv(R"d:/msc-project/data/bulk_export_122020/jobs.csv",encoding='utf-8')

# %%
jobs_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'person_uuid', 'person_name', 'org_uuid', 'org_name',
#        'started_on', 'ended_on', 'is_current', 'title', 'job_type'],
#       dtype='object')

# %%
jobs_df.head(1)
# Out:
#                                    uuid  \
# 0  697b6934-fc1f-9d63-cfb2-1a10759b378e
#
#                                                 name type  \
# 0  Ben Elowitz Co-Founder/CEO/Board of Directors ...  job
#
#                                   permalink  \
# 0  ben-elowitz-executive-wetpaint--697b6934
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/job/ben-elowitz-exe...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-25 07:03:54  2018-02-13 01:26:54
#
#                             person_uuid  person_name  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71  Ben Elowitz
#
#                                org_uuid  org_name started_on ended_on  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint        NaN      NaN
#
#    is_current                              title   job_type
# 0       False  Co-Founder/CEO/Board of Directors  executive

# %%
#drop unecessary columns
jobs_df_v1 = jobs_df.drop(columns=['type', 'permalink', 'cb_url', 'rank', 'created_at',
       'updated_at'])

# %%
jobs_df_v1.columns
# Out:
# Index(['uuid', 'name', 'person_uuid', 'person_name', 'org_uuid', 'org_name',
#        'started_on', 'ended_on', 'is_current', 'title', 'job_type'],
#       dtype='object')

# %%
#change columns name
jobs_df_v1.rename(columns={'uuid':'job_uuid','name':'job_name','person_uuid':'people_uuid'},inplace=True)

# %%
jobs_df_v1.columns
# Out:
# Index(['job_uuid', 'job_name', 'people_uuid', 'person_name', 'org_uuid',
#        'org_name', 'started_on', 'ended_on', 'is_current', 'title',
#        'job_type'],
#       dtype='object')

# %%
jobs_df.head(3)
# Out:
#                                    uuid  \
# 0  697b6934-fc1f-9d63-cfb2-1a10759b378e
# 1  b1de3765-442e-b556-9304-551c2a055901
# 2  1319cd30-f5e8-c700-0af6-64029c6f7124
#
#                                                 name type  \
# 0  Ben Elowitz Co-Founder/CEO/Board of Directors ...  job
# 1             Kevin Flaherty VP Marketing @ Wetpaint  job
# 2               Raju Vegesna Chief Evangelist @ Zoho  job
#
#                                      permalink  \
# 0     ben-elowitz-executive-wetpaint--697b6934
# 1  kevin-flaherty-executive-wetpaint--b1de3765
# 2         raju-vegesna-employee-zoho--1319cd30
#
#                                               cb_url  rank  \
# 0  https://www.crunchbase.com/job/ben-elowitz-exe...   NaN
# 1  https://www.crunchbase.com/job/kevin-flaherty-...   NaN
# 2  https://www.crunchbase.com/job/raju-vegesna-em...   NaN
#
#             created_at           updated_at  \
# 0  2007-05-25 07:03:54  2018-02-13 01:26:54
# 1  2007-05-25 07:04:16  2018-02-13 01:32:51
# 2  2007-05-25 19:33:03  2018-02-13 01:19:53
#
#                             person_uuid     person_name  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna
#
#                                org_uuid  org_name  started_on ended_on  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint         NaN      NaN
# 1  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint         NaN      NaN
# 2  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  2000-11-01      NaN
#
#    is_current                              title   job_type
# 0       False  Co-Founder/CEO/Board of Directors  executive
# 1       False                       VP Marketing  executive
# 2        True                   Chief Evangelist   employee

# %%
len(jobs_df_v1)
# Out:
# 1581722

# %%
#create founder column, 1 for founder role, 0 for non founder role
is_founder = list()

for role in list(jobs_df_v1.title):
    if 'founder' in str(role).lower():
        is_founder.append(1)
    else:
        is_founder.append(0)
        
jobs_df_v1['is_founder'] = is_founder

# %%
jobs_df_v1.columns
# Out:
# Index(['job_uuid', 'job_name', 'people_uuid', 'person_name', 'org_uuid',
#        'org_name', 'started_on', 'ended_on', 'is_current', 'title', 'job_type',
#        'is_founder'],
#       dtype='object')

# %% [markdown]
# # Save pre-processed file

# %%
#organisations + organisations_description + ipo + acquisition
main_org_df_v4.to_csv(R"d:/msc-project/data/pre-processed/organisations_preprocessed.csv",encoding='utf-8')
