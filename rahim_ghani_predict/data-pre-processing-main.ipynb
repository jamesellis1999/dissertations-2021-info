# %%
#Import basic packages
import os
import numpy as np
import pandas as pd
import csv

# %%
#import organizations.csv
data_path = os.path.join(os.getcwd(), 'data','bulk_export_122020','organizations.csv')
org_df = pd.read_csv(data_path,encoding='utf-8')
# Out:
#                                    uuid                       name  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd                   Wetpaint
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                       Zoho
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                       Digg
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec            Omidyar Network
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb                   Facebook
# 5  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9           Trinity Ventures
# 6  b08efc27-da40-505a-6f9d-c9e14247bf36                      Accel
# 7  8d5c7e48-82da-3025-dd46-346a31bab86f  Meritech Capital Partners
# 8  60485007-8856-bbac-aa1b-c535c41f5f47                  Omnidrive
# 9  4111dc8b-c0df-2d24-ed33-30cd137b3098                       Geni
#
#            type                  permalink  \
# 0  organization                   wetpaint
# 1  organization                       zoho
# 2  organization                       digg
# 3  organization            omidyar-network
# ...

# %%
org_df.head()
# Out:
#                                    uuid             name          type  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb         Facebook  organization
#
#          permalink                                             cb_url  \
# 0         wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1             zoho       https://www.crunchbase.com/organization/zoho
# 2             digg       https://www.crunchbase.com/organization/digg
# 3  omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4         facebook   https://www.crunchbase.com/organization/facebook
#
#        rank           created_at           updated_at          legal_name  \
# ...

# %%
org_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
set(org_df.num_funding_rounds)

# %%
status = list (org_df.status)

# %%
status.count ('acquired')
# Out:
# 100573

# %%
status.count ('ipo')
# Out:
# 30852

# %%
status.count ('operating')
# Out:
# 1045924

# %%
status.count ('closed')
# Out:
# 39096

# %%
list (org_df.primary_role).count('company')
# Out:
# 1146424

# %%
#import jobs.csv
data_path = os.path.join(os.getcwd(), 'data','bulk_export_122020','jobs.csv')
jobs_df = pd.read_csv(data_path,encoding='utf-8')

# %%
jobs_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'person_uuid', 'person_name', 'org_uuid', 'org_name',
#        'started_on', 'ended_on', 'is_current', 'title', 'job_type'],
#       dtype='object')

# %%
set(jobs_df.job_type)
# Out:
# {'advisor', 'board_member', 'board_observer', 'employee', 'executive'}

# %%
#import organizations_descriptions.csv
data_path = os.path.join(os.getcwd(), 'data','bulk_export_122020','organization_descriptions.csv')
org_desc_df = pd.read_csv(data_path,encoding='utf-8')

# %%
org_desc_df.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'description'],
#       dtype='object')

# %%
org_desc_df.description
# Out:
# 0         Wetpaint is a technology platform company that...
# 1         Zoho offers a suite of business, collaboration...
# 2         Digg Inc. operates a website that enables its ...
# 3         Pierre Omidyar, the founder of eBay, and his w...
# 4         Facebook is an online social networking servic...
#                                 ...
# 661708    Talk Howdy is an online community platform. Th...
# 661709    Digital Broker App of U.S Securities for Latin...
# 661710    Tidbits are creatively and beautiful free info...
# 661711    Nereus Advisors is founded and led by Bruce Co...
# 661712    Angelico Ventures is a life science focused ve...
# Name: description, Length: 661713, dtype: object

# %%
set(org_df.employee_count)
# Out:
# {'1-10',
#  '10000+',
#  '1001-5000',
#  '101-250',
#  '11-50',
#  '251-500',
#  '5001-10000',
#  '501-1000',
#  '51-100',
#  'unknown'}
